# %% [markdown]
# # DAMCC
#
# The thesis paper is available [here]([URL_TO_PAPER](https://dl.acm.org/doi/10.1145/3642970.3655829)).
#
# ## Problem Statement
#
# **Graphs:** Given a timestamp $t$, we represent each graph in the data as a tuple of its adjacency and node feature matrices:
#
# $$
# G_t = (\mathbf{X}_t, \mathbf{A}_t)
# $$
#
# where
#
# $$
# \mathbf{X}_t \in \mathbb{R}^{N \times F}, \quad \mathbf{A}_t \in \{0,1\}^{N \times N}
# $$
#
# Here, $N$ is the total number of nodes, and $F$ is the number of node features. We then represent a graph time series as a sequence of graphs over time:
#
# $$
# (G_t)_{t=0}^T = (G_1, G_2, \dots, G_T)
# $$
#
# where $T$ is the last timestamp. For our synthetically generated datasets, we have more than one such sequence of graphs. Therefore, we represent the full dataset as a set of graph sequences:
#
# $$
# \{(G_t^1)_{t=0}^T, (G_t^2)_{t=0}^T, \dots, (G_t^{L-1})_{t=0}^T, (G_t^L)_{t=0}^T \}
# $$
#
# Given an unseen graph $G_t$ from such a dataset, our task is to predict $G_{t+1}$.

# %%
import pickle
import networkx as nx
import matplotlib.pyplot as plt
import os
import sys
import pandas as pd

# Add the parent directory of utils to the Python path
sys.path.append(os.path.join(os.getcwd(), '..'))
# from utils.utils import display_data_nice

# %% [markdown]
# First, let us create the dataset. Let us generate a dataset based on the Barabási–Albert (BA) model. BA is a widely used algorithm in network science for generating scale-free networks, which are characterized by a power-law degree distribution. See [wikipedia]([URL_TO_PAPER](https://en.wikipedia.org/wiki/Barab%C3%A1si%E2%80%93Albert_model))
#  for more details. For us, it suffices us to know that this is some non-random sequence of graphs. We generate a BA dataset via a yaml config file in the data directory. Lets use the ba.yaml as an example.

# %%
# Generate data using the specified YAML configuration file
# -c: path to the configuration file
# -p: path to the directory where the generated data will be saved
# -d: name of the dataset
# !python ../data/generate_data.py \
    -c ../data/data_configs/ba.yaml \
    -p ../data/datasets \
    -d ba
# Out:
# 100%|███████████████████████████████████████████| 12/12 [00:02<00:00,  5.50it/s]
# 12

# %% [markdown]
# This process yields a list of 12 graph sequences with 6 graphs in each sequence each of which is a networkx.Graph object. Let us now see what this generated data looks like. Let us use the first sequence out of the three.

# %%
# Open the dataset file and load the data using pickle
with open('../data/datasets/ba.pkl', 'rb') as file:
    data = pickle.load(file)

# Set up the positions for the nodes for plotting using spring layout
# Use a fixed seed for reproducibility
graph = data[0][-1]
pos = nx.spring_layout(graph, seed=4)  
pos[2] = [0.1, -0.5]  # Manually adjust the position of node 2

# Plot the first graph in the data list
fig, axes = plt.subplots(2, len(data[0]) // 2, figsize=(20, 11))
axes = axes.flatten()  # Flatten the 2D array of axes

# Iterate over each graph in the first sequence and plot it
for i, graph in enumerate(data[0]):
    ax = axes[i]
    nx.draw(graph, pos, with_labels=True, node_color='skyblue', node_size=250, edge_color='gray', 
            font_size=10, font_color='black', font_weight='bold', ax=ax)
    ax.set_title(f"Timestep {i+1}")

# Display the plot
plt.show()

# %% [markdown]
# Then, we need to preprocess to separate to train, validate , and test:

# %%
# Preprocess the data using the specified dataset file
# -d: path to the dataset file
# -s: path to the directory where the processed data will be saved
# -t: proportion of the data to be used for training
# -v: proportion of the data to be used for validation
# -r: whether to shuffle the data (False means no shuffling)
# !python ../data/preprocess_data.py \
    -d ../data/datasets/ba.pkl \
    -s ../data/processed_datasets/ba/graph_data/ \
    -t 0.5 \
    -v 0.5 \
    -r False
# Out:
# Randomizing
# Number of Training TS:  3
# Number of Val TS:  3
# Number of Test TS:  6
# TS length (T):  6
# Saving Graphs
# 6
# 6
# 6
# Computing Deltas
# Converting to networkx format
# 100%|██████████████████████████████████████████| 15/15 [00:00<00:00, 524.66it/s]
# Setting attributes.
# 100%|████████████████████████████████████████| 15/15 [00:00<00:00, 35464.80it/s]
# Computing Deltas
# Converting to networkx format
# 100%|█████████████████████████████████████████| 15/15 [00:00<00:00, 2741.26it/s]
# Setting attributes.
# 100%|███████████████████████████████████████| 15/15 [00:00<00:00, 100023.15it/s]

# %% [markdown]
# You should now have the following files in the data directory:
# ba_test_graphs_raw.pkl  ba_train_graphs.pkl  ba_train_graphs_raw.pkl  ba_val_graphs.pkl  ba_val_graphs_raw.pkl. The files with no -raw suffix are for DAMNETS and AGE models. Let us now see processed format of our data:

# %%
# The non-raw datasets are for the DAMNETS model
# Load the training dataset
with open('../data/processed_datasets/ba/graph_data/ba_train_graphs_raw.pkl', 'rb') as file:
    train_data = pickle.load(file)

# Load the validation dataset
with open('../data/processed_datasets/ba/graph_data/ba_val_graphs_raw.pkl', 'rb') as file:
    val_data = pickle.load(file)

# Load the test dataset
with open('../data/processed_datasets/ba/graph_data/ba_test_graphs_raw.pkl', 'rb') as file:
    test_data = pickle.load(file)

# Combine the datasets into a list for easier iteration
datasets = [train_data, val_data, test_data]
dataset_names = ['Train', 'Validation', 'Test']

# Iterate over each dataset and plot the graphs
for dataset, name in zip(datasets, dataset_names):
    # Create a figure with subplots for each graph in the dataset
    fig, axes = plt.subplots(1, len(dataset[0]), figsize=(20, 3))
    axes = axes.flatten()  # Flatten the 2D array of axes

    # Iterate over each graph in the dataset and plot it
    for i, graph in enumerate(dataset[0]):
        ax = axes[i]
        nx.draw(graph, pos, with_labels=True, node_color='skyblue', node_size=250, edge_color='gray', 
                font_size=10, font_color='black', font_weight='bold', ax=ax)
        ax.set_title(f"Timestep {i+1}")

    # Set the title for the entire figure
    fig.suptitle(f"{name} Dataset", fontsize=16)
    plt.show()

# %% [markdown]
# All looks in order. Let us now convert these graphs to CC format:

# %%
# Lift the training graphs to CC format and save the output
# !python ../utils/process_graph_to_cc.py -i ../data/processed_datasets/ba/graph_data/ba_train_graphs_raw.pkl -o ../data/processed_datasets/ba/CC_data

# Lift the validation graphs to CC format and save the output
# !python ../utils/process_graph_to_cc.py -i ../data/processed_datasets/ba/graph_data/ba_val_graphs_raw.pkl -o ../data/processed_datasets/ba/CC_data

# Lift the test graphs to CC format and save the output
# !python ../utils/process_graph_to_cc.py -i ../data/processed_datasets/ba/graph_data/ba_test_graphs_raw.pkl -o ../data/processed_datasets/ba/CC_data
# Out:
# Converting graphs to ccs
# 100%|████████████████████████████████████████████| 6/6 [00:00<00:00, 496.07it/s]
# Converting graphs to ccs
# 100%|████████████████████████████████████████████| 6/6 [00:00<00:00, 663.34it/s]
# Converting graphs to ccs
# 100%|████████████████████████████████████████████| 6/6 [00:00<00:00, 589.79it/s]
# Setting x_0
# 100%|██████████████████████████████████████████| 6/6 [00:00<00:00, 35098.78it/s]
# Setting x_0
# 100%|██████████████████████████████████████████| 6/6 [00:00<00:00, 74017.13it/s]
# Setting x_0
# 100%|██████████████████████████████████████████| 6/6 [00:00<00:00, 90851.35it/s]
# 100%|███████████████████████████████████████████| 6/6 [00:00<00:00, 1568.94it/s]
# 100%|███████████████████████████████████████████| 6/6 [00:00<00:00, 2668.13it/s]
# 100%|███████████████████████████████████████████| 6/6 [00:00<00:00, 4854.52it/s]
# Data saved to ../data/processed_datasets/ba/CC_data/ba_train_ccs.pkl
# Converting graphs to ccs
# 100%|████████████████████████████████████████████| 6/6 [00:00<00:00, 309.53it/s]
# Converting graphs to ccs
# 100%|████████████████████████████████████████████| 6/6 [00:00<00:00, 470.65it/s]
# Converting graphs to ccs
# 100%|████████████████████████████████████████████| 6/6 [00:00<00:00, 424.63it/s]
# Setting x_0
# 100%|██████████████████████████████████████████| 6/6 [00:00<00:00, 35951.18it/s]
# Setting x_0
# 100%|██████████████████████████████████████████| 6/6 [00:00<00:00, 71493.82it/s]
# Setting x_0
# 100%|██████████████████████████████████████████| 6/6 [00:00<00:00, 81973.37it/s]
# 100%|███████████████████████████████████████████| 6/6 [00:00<00:00, 5058.46it/s]
# 100%|███████████████████████████████████████████| 6/6 [00:00<00:00, 5420.16it/s]
# 100%|███████████████████████████████████████████| 6/6 [00:00<00:00, 3726.61it/s]
# Data saved to ../data/processed_datasets/ba/CC_data/ba_val_ccs.pkl
# Converting graphs to ccs
# 100%|████████████████████████████████████████████| 6/6 [00:00<00:00, 237.67it/s]
# Converting graphs to ccs
# 100%|████████████████████████████████████████████| 6/6 [00:00<00:00, 620.21it/s]
# Converting graphs to ccs
# 100%|████████████████████████████████████████████| 6/6 [00:00<00:00, 387.47it/s]
# Converting graphs to ccs
# 100%|████████████████████████████████████████████| 6/6 [00:00<00:00, 438.02it/s]
# Converting graphs to ccs
# 100%|████████████████████████████████████████████| 6/6 [00:00<00:00, 488.05it/s]
# Converting graphs to ccs
# 100%|████████████████████████████████████████████| 6/6 [00:00<00:00, 680.97it/s]
# Setting x_0
# 100%|██████████████████████████████████████████| 6/6 [00:00<00:00, 33870.56it/s]
# Setting x_0
# 100%|██████████████████████████████████████████| 6/6 [00:00<00:00, 63072.24it/s]
# Setting x_0
# 100%|██████████████████████████████████████████| 6/6 [00:00<00:00, 76959.71it/s]
# Setting x_0
# 100%|██████████████████████████████████████████| 6/6 [00:00<00:00, 87992.39it/s]
# Setting x_0
# 100%|██████████████████████████████████████████| 6/6 [00:00<00:00, 69711.42it/s]
# Setting x_0
# 100%|██████████████████████████████████████████| 6/6 [00:00<00:00, 74235.47it/s]
# 100%|███████████████████████████████████████████| 6/6 [00:00<00:00, 4664.66it/s]
# 100%|███████████████████████████████████████████| 6/6 [00:00<00:00, 5047.30it/s]
# 100%|███████████████████████████████████████████| 6/6 [00:00<00:00, 3821.11it/s]
# 100%|███████████████████████████████████████████| 6/6 [00:00<00:00, 5033.16it/s]
# 100%|███████████████████████████████████████████| 6/6 [00:00<00:00, 5110.85it/s]
# 100%|███████████████████████████████████████████| 6/6 [00:00<00:00, 4974.47it/s]
# Data saved to ../data/processed_datasets/ba/CC_data/ba_test_ccs.pkl

# %% [markdown]
# Its is difficult to visualise CC's so we won't. We now train the model:

# %%
# Train the DAMCC model using the specified parameters
# --train: flag to indicate training mode
# --data_name: name of the dataset
# --train_file: path to the training data file in CC format
# --val_file: path to the validation data file in CC format
# --save_dir: directory where the trained model and other outputs will be saved
# --max_epochs: maximum number of training epochs
# --lr: learning rate for the optimizer
# !python ../run_damcc.py \
    --train \
    --data_name ba \
    --train_file ../data/processed_datasets/ba/CC_data/ba_train_ccs.pkl \
    --val_file ../data/processed_datasets/ba/CC_data/ba_val_ccs.pkl \
    --save_dir ../experiments \
    --max_epochs 2 \
    --lr 0.001
# Out:
# Using device: cpu
#   0%|                                                    | 0/15 [00:00<?, ?it/s]At Epoch 1:
# /opt/anaconda3/envs/damcc_eval/lib/python3.11/site-packages/topomodelx/nn/combinatorial/hmc_layer.py:680: UserWarning: Sparse CSR tensor support is in beta state. If you miss a functionality in the sparse tensor support, please submit a feature request to https://github.com/pytorch/pytorch/issues. (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/SparseCsrTensorImpl.cpp:56.)
#   A_p = torch.sparse.mm(A_p, neighborhood)
# generating rows
#
#   0%|                                                     | 0/4 [00:00<?, ?it/s]
# 100%|█████████████████████████████████████████████| 4/4 [00:00<00:00, 26.72it/s]
# generating rows
#
# 100%|████████████████████████████████████████████| 4/4 [00:00<00:00, 123.97it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  4
# new size:  8
# generating rows
#
# 100%|████████████████████████████████████████████| 1/1 [00:00<00:00, 425.17it/s]
# generating rows
#
# 100%|████████████████████████████████████████████| 1/1 [00:00<00:00, 247.52it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  1
# new size:  2
# ONE FORWARD PASS DONE
# ONE BACKWARD PASS DONE
#   7%|██▉                                         | 1/15 [00:00<00:09,  1.43it/s]At Epoch 1:
# generating rows
#
# 100%|█████████████████████████████████████████████| 8/8 [00:00<00:00, 91.65it/s]
# generating rows
#
# 100%|████████████████████████████████████████████| 8/8 [00:00<00:00, 159.45it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  8
# new size:  16
# generating rows
#
# 100%|████████████████████████████████████████████| 3/3 [00:00<00:00, 131.76it/s]
# generating rows
#
# 100%|█████████████████████████████████████████████| 3/3 [00:00<00:00, 64.05it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  3
# new size:  6
# ONE FORWARD PASS DONE
# ONE BACKWARD PASS DONE
#  13%|█████▊                                      | 2/15 [00:01<00:09,  1.41it/s]At Epoch 1:
# generating rows
#
#   0%|                                                    | 0/12 [00:00<?, ?it/s]
# 100%|███████████████████████████████████████████| 12/12 [00:00<00:00, 85.82it/s]
# generating rows
#
#   0%|                                                    | 0/12 [00:00<?, ?it/s]
# 100%|███████████████████████████████████████████| 12/12 [00:00<00:00, 86.38it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  12
# new size:  24
# generating rows
#
# 100%|████████████████████████████████████████████| 3/3 [00:00<00:00, 132.63it/s]
# generating rows
#
# 100%|█████████████████████████████████████████████| 3/3 [00:00<00:00, 66.86it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  3
# new size:  6
# ONE FORWARD PASS DONE
# ONE BACKWARD PASS DONE
#  20%|████████▊                                   | 3/15 [00:02<00:09,  1.32it/s]At Epoch 1:
# generating rows
#
#   0%|                                                    | 0/16 [00:00<?, ?it/s]
# 100%|██████████████████████████████████████████| 16/16 [00:00<00:00, 130.23it/s]
# generating rows
#
#   0%|                                                    | 0/16 [00:00<?, ?it/s]
# 100%|██████████████████████████████████████████| 16/16 [00:00<00:00, 130.51it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  16
# new size:  32
# generating rows
#
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 188.37it/s]
# generating rows
#
# 100%|█████████████████████████████████████████████| 5/5 [00:00<00:00, 89.11it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  5
# new size:  10
# ONE FORWARD PASS DONE
# ONE BACKWARD PASS DONE
#  27%|███████████▋                                | 4/15 [00:03<00:08,  1.25it/s]At Epoch 1:
# generating rows
#
#   0%|                                                    | 0/20 [00:00<?, ?it/s]
#  50%|█████████████████████▌                     | 10/20 [00:00<00:00, 97.34it/s]
# 100%|███████████████████████████████████████████| 20/20 [00:00<00:00, 92.79it/s]
# generating rows
#
#   0%|                                                    | 0/20 [00:00<?, ?it/s]
# 100%|██████████████████████████████████████████| 20/20 [00:00<00:00, 113.34it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  20
# new size:  40
# generating rows
#
#   0%|                                                     | 0/7 [00:00<?, ?it/s]
# 100%|█████████████████████████████████████████████| 7/7 [00:00<00:00, 57.14it/s]
# generating rows
#
#   0%|                                                     | 0/7 [00:00<?, ?it/s]
# 100%|█████████████████████████████████████████████| 7/7 [00:00<00:00, 55.22it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  7
# new size:  14
# ONE FORWARD PASS DONE
# ONE BACKWARD PASS DONE
#  33%|██████████████▋                             | 5/15 [00:04<00:10,  1.01s/it]At Epoch 1:
# generating rows
#
# 100%|████████████████████████████████████████████| 4/4 [00:00<00:00, 125.12it/s]
# generating rows
#
# 100%|████████████████████████████████████████████| 4/4 [00:00<00:00, 321.91it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  4
# new size:  8
# generating rows
#
# 100%|█████████████████████████████████████████████| 1/1 [00:00<00:00, 79.35it/s]
# generating rows
#
# 100%|████████████████████████████████████████████| 1/1 [00:00<00:00, 184.61it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  1
# new size:  2
# ONE FORWARD PASS DONE
# ONE BACKWARD PASS DONE
#  40%|█████████████████▌                          | 6/15 [00:04<00:06,  1.36it/s]At Epoch 1:
# generating rows
#
#   0%|                                                     | 0/8 [00:00<?, ?it/s]
# 100%|█████████████████████████████████████████████| 8/8 [00:00<00:00, 43.32it/s]
# generating rows
#
#   0%|                                                     | 0/8 [00:00<?, ?it/s]
# 100%|█████████████████████████████████████████████| 8/8 [00:00<00:00, 60.66it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  8
# new size:  16
# generating rows
#
# 100%|████████████████████████████████████████████| 3/3 [00:00<00:00, 100.67it/s]
# generating rows
#
# 100%|█████████████████████████████████████████████| 3/3 [00:00<00:00, 71.29it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  3
# new size:  6
# ONE FORWARD PASS DONE
# ONE BACKWARD PASS DONE
#  47%|████████████████████▌                       | 7/15 [00:05<00:05,  1.34it/s]At Epoch 1:
# generating rows
#
# 100%|██████████████████████████████████████████| 12/12 [00:00<00:00, 125.39it/s]
# generating rows
#
#   0%|                                                    | 0/12 [00:00<?, ?it/s]
# 100%|███████████████████████████████████████████| 12/12 [00:00<00:00, 89.95it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  12
# new size:  24
# generating rows
#
# 100%|████████████████████████████████████████████| 3/3 [00:00<00:00, 396.77it/s]
# generating rows
#
# 100%|████████████████████████████████████████████| 3/3 [00:00<00:00, 114.18it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  3
# new size:  6
# ONE FORWARD PASS DONE
# ONE BACKWARD PASS DONE
#  53%|███████████████████████▍                    | 8/15 [00:06<00:05,  1.34it/s]At Epoch 1:
# generating rows
#
#   0%|                                                    | 0/16 [00:00<?, ?it/s]
# 100%|██████████████████████████████████████████| 16/16 [00:00<00:00, 125.27it/s]
# generating rows
#
#   0%|                                                    | 0/16 [00:00<?, ?it/s]
# 100%|██████████████████████████████████████████| 16/16 [00:00<00:00, 132.16it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  16
# new size:  32
# generating rows
#
# 100%|█████████████████████████████████████████████| 5/5 [00:00<00:00, 93.56it/s]
# generating rows
#
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 132.77it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  5
# new size:  10
# ONE FORWARD PASS DONE
# ONE BACKWARD PASS DONE
#  60%|██████████████████████████▍                 | 9/15 [00:07<00:04,  1.25it/s]At Epoch 1:
# generating rows
#
#   0%|                                                    | 0/20 [00:00<?, ?it/s]
# 100%|██████████████████████████████████████████| 20/20 [00:00<00:00, 160.50it/s]
# generating rows
#
#   0%|                                                    | 0/20 [00:00<?, ?it/s]
#  45%|███████████████████▊                        | 9/20 [00:00<00:00, 84.35it/s]
# 100%|███████████████████████████████████████████| 20/20 [00:00<00:00, 59.19it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  20
# new size:  40
# generating rows
#
# 100%|█████████████████████████████████████████████| 7/7 [00:00<00:00, 89.47it/s]
# generating rows
#
# 100%|█████████████████████████████████████████████| 7/7 [00:00<00:00, 95.52it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  7
# new size:  14
# ONE FORWARD PASS DONE
# ONE BACKWARD PASS DONE
#  67%|████████████████████████████▋              | 10/15 [00:08<00:05,  1.02s/it]At Epoch 1:
# generating rows
#
# 100%|████████████████████████████████████████████| 4/4 [00:00<00:00, 109.91it/s]
# generating rows
#
# 100%|████████████████████████████████████████████| 4/4 [00:00<00:00, 141.35it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  4
# new size:  8
# generating rows
#
# 100%|█████████████████████████████████████████████| 1/1 [00:00<00:00, 82.79it/s]
# generating rows
#
# 100%|█████████████████████████████████████████████| 1/1 [00:00<00:00, 93.99it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  1
# new size:  2
# ONE FORWARD PASS DONE
# ONE BACKWARD PASS DONE
#  73%|███████████████████████████████▌           | 11/15 [00:08<00:03,  1.27it/s]At Epoch 1:
# generating rows
#
# 100%|████████████████████████████████████████████| 8/8 [00:00<00:00, 110.74it/s]
# generating rows
#
# 100%|█████████████████████████████████████████████| 8/8 [00:00<00:00, 85.66it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  8
# new size:  16
# generating rows
#
# 100%|█████████████████████████████████████████████| 3/3 [00:00<00:00, 58.58it/s]
# generating rows
#
# 100%|█████████████████████████████████████████████| 3/3 [00:00<00:00, 98.86it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  3
# new size:  6
# ONE FORWARD PASS DONE
# ONE BACKWARD PASS DONE
#  80%|██████████████████████████████████▍        | 12/15 [00:09<00:02,  1.33it/s]At Epoch 1:
# generating rows
#
#   0%|                                                    | 0/12 [00:00<?, ?it/s]
# 100%|███████████████████████████████████████████| 12/12 [00:00<00:00, 74.24it/s]
# generating rows
#
#   0%|                                                    | 0/12 [00:00<?, ?it/s]
# 100%|███████████████████████████████████████████| 12/12 [00:00<00:00, 74.67it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  12
# new size:  24
# generating rows
#
# 100%|████████████████████████████████████████████| 3/3 [00:00<00:00, 436.36it/s]
# generating rows
#
# 100%|████████████████████████████████████████████| 3/3 [00:00<00:00, 140.77it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  3
# new size:  6
# ONE FORWARD PASS DONE
# ONE BACKWARD PASS DONE
#  87%|█████████████████████████████████████▎     | 13/15 [00:10<00:01,  1.12it/s]At Epoch 1:
# generating rows
#
#   0%|                                                    | 0/16 [00:00<?, ?it/s]
# 100%|██████████████████████████████████████████| 16/16 [00:00<00:00, 101.64it/s]
# generating rows
#
#   0%|                                                    | 0/16 [00:00<?, ?it/s]
# 100%|██████████████████████████████████████████| 16/16 [00:00<00:00, 108.75it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  16
# new size:  32
# generating rows
#
# 100%|█████████████████████████████████████████████| 5/5 [00:00<00:00, 85.61it/s]
# generating rows
#
# 100%|█████████████████████████████████████████████| 5/5 [00:00<00:00, 70.61it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  5
# new size:  10
# ONE FORWARD PASS DONE
# ONE BACKWARD PASS DONE
#  93%|████████████████████████████████████████▏  | 14/15 [00:11<00:00,  1.06it/s]At Epoch 1:
# generating rows
#
#   0%|                                                    | 0/20 [00:00<?, ?it/s]
# 100%|███████████████████████████████████████████| 20/20 [00:00<00:00, 96.39it/s]
# generating rows
#
#   0%|                                                    | 0/20 [00:00<?, ?it/s]
#  45%|███████████████████▊                        | 9/20 [00:00<00:00, 88.85it/s]
# 100%|███████████████████████████████████████████| 20/20 [00:00<00:00, 97.47it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  20
# new size:  40
# generating rows
#
# 100%|█████████████████████████████████████████████| 5/5 [00:00<00:00, 50.61it/s]
# generating rows
#
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 131.73it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  5
# new size:  10
# ONE FORWARD PASS DONE
# ONE BACKWARD PASS DONE
# 100%|███████████████████████████████████████████| 15/15 [00:13<00:00,  1.13it/s]
# generating rows
# 100%|████████████████████████████████████████████| 4/4 [00:00<00:00, 180.23it/s]
# generating rows
# 100%|████████████████████████████████████████████| 4/4 [00:00<00:00, 109.39it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  4
# new size:  8
# generating rows
# 100%|█████████████████████████████████████████████| 1/1 [00:00<00:00, 19.44it/s]
# generating rows
# 100%|████████████████████████████████████████████| 1/1 [00:00<00:00, 150.02it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  1
# new size:  2
# generating rows
# 100%|████████████████████████████████████████████| 8/8 [00:00<00:00, 143.55it/s]
# generating rows
# 100%|████████████████████████████████████████████| 8/8 [00:00<00:00, 172.84it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  8
# new size:  16
# generating rows
# 100%|████████████████████████████████████████████| 3/3 [00:00<00:00, 209.89it/s]
# generating rows
# 100%|████████████████████████████████████████████| 3/3 [00:00<00:00, 339.75it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  3
# new size:  6
# generating rows
# 100%|██████████████████████████████████████████| 12/12 [00:00<00:00, 160.09it/s]
# generating rows
# 100%|██████████████████████████████████████████| 12/12 [00:00<00:00, 152.03it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  12
# new size:  24
# generating rows
# 100%|█████████████████████████████████████████████| 3/3 [00:00<00:00, 44.83it/s]
# generating rows
# 100%|█████████████████████████████████████████████| 3/3 [00:00<00:00, 55.09it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  3
# new size:  6
# generating rows
# 100%|██████████████████████████████████████████| 16/16 [00:00<00:00, 105.45it/s]
# generating rows
# 100%|███████████████████████████████████████████| 16/16 [00:00<00:00, 91.08it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  16
# new size:  32
# generating rows
# 100%|████████████████████████████████████████████| 3/3 [00:00<00:00, 201.53it/s]
# generating rows
# 100%|████████████████████████████████████████████| 3/3 [00:00<00:00, 128.47it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  3
# new size:  6
# generating rows
# 100%|██████████████████████████████████████████| 20/20 [00:00<00:00, 115.70it/s]
# generating rows
# 100%|██████████████████████████████████████████| 20/20 [00:00<00:00, 185.74it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  20
# new size:  40
# generating rows
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 274.12it/s]
# generating rows
# 100%|█████████████████████████████████████████████| 5/5 [00:00<00:00, 75.18it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  5
# new size:  10
# generating rows
# 100%|████████████████████████████████████████████| 4/4 [00:00<00:00, 124.41it/s]
# generating rows
# 100%|████████████████████████████████████████████| 4/4 [00:00<00:00, 158.00it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  4
# new size:  8
# generating rows
# 100%|████████████████████████████████████████████| 1/1 [00:00<00:00, 339.56it/s]
# generating rows
# 100%|████████████████████████████████████████████| 1/1 [00:00<00:00, 191.43it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  1
# new size:  2
# generating rows
# 100%|████████████████████████████████████████████| 8/8 [00:00<00:00, 203.96it/s]
# generating rows
# 100%|████████████████████████████████████████████| 8/8 [00:00<00:00, 214.22it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  8
# new size:  16
# generating rows
# 100%|█████████████████████████████████████████████| 3/3 [00:00<00:00, 82.43it/s]
# generating rows
# 100%|█████████████████████████████████████████████| 3/3 [00:00<00:00, 88.74it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  3
# new size:  6
# generating rows
# 100%|██████████████████████████████████████████| 12/12 [00:00<00:00, 147.09it/s]
# generating rows
# 100%|██████████████████████████████████████████| 12/12 [00:00<00:00, 171.29it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  12
# new size:  24
# generating rows
# 100%|█████████████████████████████████████████████| 5/5 [00:00<00:00, 67.30it/s]
# generating rows
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 190.50it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  5
# new size:  10
# generating rows
# 100%|██████████████████████████████████████████| 16/16 [00:00<00:00, 160.77it/s]
# generating rows
# 100%|██████████████████████████████████████████| 16/16 [00:00<00:00, 187.92it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  16
# new size:  32
# generating rows
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 256.86it/s]
# generating rows
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 141.97it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  5
# new size:  10
# generating rows
# 100%|██████████████████████████████████████████| 20/20 [00:00<00:00, 128.81it/s]
# generating rows
# 100%|███████████████████████████████████████████| 20/20 [00:00<00:00, 98.24it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  20
# new size:  40
# generating rows
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 120.25it/s]
# generating rows
# 100%|█████████████████████████████████████████████| 5/5 [00:00<00:00, 47.18it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  5
# new size:  10
# generating rows
# 100%|████████████████████████████████████████████| 4/4 [00:00<00:00, 112.46it/s]
# generating rows
# 100%|█████████████████████████████████████████████| 4/4 [00:00<00:00, 95.17it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  4
# new size:  8
# generating rows
# 100%|████████████████████████████████████████████| 1/1 [00:00<00:00, 149.15it/s]
# generating rows
# 100%|█████████████████████████████████████████████| 1/1 [00:00<00:00, 70.15it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  1
# new size:  2
# generating rows
# 100%|████████████████████████████████████████████| 8/8 [00:00<00:00, 295.34it/s]
# generating rows
# 100%|█████████████████████████████████████████████| 8/8 [00:00<00:00, 98.44it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  8
# new size:  16
# generating rows
# 100%|█████████████████████████████████████████████| 3/3 [00:00<00:00, 59.30it/s]
# generating rows
# 100%|█████████████████████████████████████████████| 3/3 [00:00<00:00, 88.42it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  3
# new size:  6
# generating rows
# 100%|██████████████████████████████████████████| 12/12 [00:00<00:00, 171.64it/s]
# generating rows
# 100%|██████████████████████████████████████████| 12/12 [00:00<00:00, 144.94it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  12
# new size:  24
# generating rows
# 100%|████████████████████████████████████████████| 4/4 [00:00<00:00, 112.59it/s]
# generating rows
# 100%|█████████████████████████████████████████████| 4/4 [00:00<00:00, 98.55it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  4
# new size:  8
# generating rows
# 100%|██████████████████████████████████████████| 16/16 [00:00<00:00, 135.76it/s]
# generating rows
# 100%|██████████████████████████████████████████| 16/16 [00:00<00:00, 113.71it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  16
# new size:  32
# generating rows
# 100%|█████████████████████████████████████████████| 4/4 [00:00<00:00, 63.33it/s]
# generating rows
# 100%|█████████████████████████████████████████████| 4/4 [00:00<00:00, 85.28it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  4
# new size:  8
# generating rows
# 100%|███████████████████████████████████████████| 20/20 [00:00<00:00, 93.49it/s]
# generating rows
# 100%|██████████████████████████████████████████| 20/20 [00:00<00:00, 129.51it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  20
# new size:  40
# generating rows
# 100%|█████████████████████████████████████████████| 5/5 [00:00<00:00, 63.28it/s]
# generating rows
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 195.33it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  5
# new size:  10
#
#
#                           )                           (           )       (
#  (                     ( /(               )           )\   (   ( /(   (   )\ )
#  )\   `  )    (    (   )\())   (   (     (     `  )  ((_) ))\  )\()) ))\ (()/(
# ((_)  /(/(    )\   )\ ((_)\    )\  )\    )\  ' /(/(   _  /((_)(_))/ /((_) ((_))
# | __|((_)_\  ((_) ((_)| |(_)  ((_)((_) _((_)) ((_)_\ | |(_))  | |_ (_))   _| |
# | _| | '_ \)/ _ \/ _| | ' \  / _|/ _ \| '  \()| '_ \)| |/ -_) |  _|/ -_)/ _` |
# |___|| .__/ \___/\__| |_||_| \__|\___/|_|_|_| | .__/ |_|\___|  \__|\___|\__,_|
#      |_|                                      |_|
#
# Epoch 1:
# 🔥 Training Loss: 0.865055, Validation Loss: 0.859347
#   0%|                                                    | 0/15 [00:00<?, ?it/s]At Epoch 2:
# generating rows
#
# 100%|████████████████████████████████████████████| 4/4 [00:00<00:00, 142.47it/s]
# generating rows
#
# 100%|█████████████████████████████████████████████| 4/4 [00:00<00:00, 50.64it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  4
# new size:  8
# generating rows
#
# 100%|████████████████████████████████████████████| 1/1 [00:00<00:00, 122.08it/s]
# generating rows
#
# 100%|█████████████████████████████████████████████| 1/1 [00:00<00:00, 53.10it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  1
# new size:  2
# ONE FORWARD PASS DONE
# ONE BACKWARD PASS DONE
#   7%|██▉                                         | 1/15 [00:00<00:04,  3.43it/s]At Epoch 2:
# generating rows
#
# 100%|████████████████████████████████████████████| 8/8 [00:00<00:00, 205.18it/s]
# generating rows
#
# 100%|█████████████████████████████████████████████| 8/8 [00:00<00:00, 89.90it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  8
# new size:  16
# generating rows
#
# 100%|█████████████████████████████████████████████| 3/3 [00:00<00:00, 75.86it/s]
# generating rows
#
# 100%|█████████████████████████████████████████████| 3/3 [00:00<00:00, 66.30it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  3
# new size:  6
# ONE FORWARD PASS DONE
# ONE BACKWARD PASS DONE
#  13%|█████▊                                      | 2/15 [00:00<00:06,  2.13it/s]At Epoch 2:
# generating rows
#
# 100%|██████████████████████████████████████████| 12/12 [00:00<00:00, 140.69it/s]
# generating rows
#
# 100%|██████████████████████████████████████████| 12/12 [00:00<00:00, 145.65it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  12
# new size:  24
# generating rows
#
# 100%|█████████████████████████████████████████████| 3/3 [00:00<00:00, 32.77it/s]
# generating rows
#
# 100%|████████████████████████████████████████████| 3/3 [00:00<00:00, 112.20it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  3
# new size:  6
# ONE FORWARD PASS DONE
# ONE BACKWARD PASS DONE
#  20%|████████▊                                   | 3/15 [00:01<00:06,  1.81it/s]At Epoch 2:
# generating rows
#
#   0%|                                                    | 0/16 [00:00<?, ?it/s]
# 100%|██████████████████████████████████████████| 16/16 [00:00<00:00, 130.06it/s]
# generating rows
#
#   0%|                                                    | 0/16 [00:00<?, ?it/s]
# 100%|██████████████████████████████████████████| 16/16 [00:00<00:00, 125.92it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  16
# new size:  32
# generating rows
#
# 100%|█████████████████████████████████████████████| 5/5 [00:00<00:00, 91.75it/s]
# generating rows
#
# 100%|█████████████████████████████████████████████| 5/5 [00:00<00:00, 80.79it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  5
# new size:  10
# ONE FORWARD PASS DONE
# ONE BACKWARD PASS DONE
#  27%|███████████▋                                | 4/15 [00:02<00:07,  1.43it/s]At Epoch 2:
# generating rows
#
#   0%|                                                    | 0/20 [00:00<?, ?it/s]
#  40%|█████████████████▌                          | 8/20 [00:00<00:00, 73.51it/s]
# 100%|███████████████████████████████████████████| 20/20 [00:00<00:00, 90.42it/s]
# generating rows
#
#   0%|                                                    | 0/20 [00:00<?, ?it/s]
# 100%|██████████████████████████████████████████| 20/20 [00:00<00:00, 125.41it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  20
# new size:  40
# generating rows
#
# 100%|████████████████████████████████████████████| 7/7 [00:00<00:00, 105.91it/s]
# generating rows
#
# 100%|█████████████████████████████████████████████| 7/7 [00:00<00:00, 92.82it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  7
# new size:  14
# ONE FORWARD PASS DONE
# ONE BACKWARD PASS DONE
#  33%|██████████████▋                             | 5/15 [00:03<00:09,  1.05it/s]At Epoch 2:
# generating rows
#
# 100%|████████████████████████████████████████████| 4/4 [00:00<00:00, 132.19it/s]
# generating rows
#
# 100%|████████████████████████████████████████████| 4/4 [00:00<00:00, 127.66it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  4
# new size:  8
# generating rows
#
# 100%|████████████████████████████████████████████| 1/1 [00:00<00:00, 651.90it/s]
# generating rows
#
# 100%|█████████████████████████████████████████████| 1/1 [00:00<00:00, 32.33it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  1
# new size:  2
# ONE FORWARD PASS DONE
# ONE BACKWARD PASS DONE
#  40%|█████████████████▌                          | 6/15 [00:04<00:06,  1.40it/s]At Epoch 2:
# generating rows
#
# 100%|████████████████████████████████████████████| 8/8 [00:00<00:00, 105.85it/s]
# generating rows
#
# 100%|████████████████████████████████████████████| 8/8 [00:00<00:00, 115.12it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  8
# new size:  16
# generating rows
#
# 100%|████████████████████████████████████████████| 3/3 [00:00<00:00, 102.34it/s]
# generating rows
#
# 100%|████████████████████████████████████████████| 3/3 [00:00<00:00, 159.22it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  3
# new size:  6
# ONE FORWARD PASS DONE
# ONE BACKWARD PASS DONE
#  47%|████████████████████▌                       | 7/15 [00:04<00:05,  1.50it/s]At Epoch 2:
# generating rows
#
#   0%|                                                    | 0/12 [00:00<?, ?it/s]
# 100%|██████████████████████████████████████████| 12/12 [00:00<00:00, 100.90it/s]
# generating rows
#
#   0%|                                                    | 0/12 [00:00<?, ?it/s]
# 100%|██████████████████████████████████████████| 12/12 [00:00<00:00, 107.65it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  12
# new size:  24
# generating rows
#
# 100%|████████████████████████████████████████████| 3/3 [00:00<00:00, 140.68it/s]
# generating rows
#
# 100%|█████████████████████████████████████████████| 3/3 [00:00<00:00, 82.76it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  3
# new size:  6
# ONE FORWARD PASS DONE
# ONE BACKWARD PASS DONE
#  53%|███████████████████████▍                    | 8/15 [00:05<00:04,  1.43it/s]At Epoch 2:
# generating rows
#
#   0%|                                                    | 0/16 [00:00<?, ?it/s]
# 100%|██████████████████████████████████████████| 16/16 [00:00<00:00, 159.47it/s]
# generating rows
#
#   0%|                                                    | 0/16 [00:00<?, ?it/s]
# 100%|██████████████████████████████████████████| 16/16 [00:00<00:00, 106.56it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  16
# new size:  32
# generating rows
#
# 100%|█████████████████████████████████████████████| 5/5 [00:00<00:00, 68.53it/s]
# generating rows
#
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 182.29it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  5
# new size:  10
# ONE FORWARD PASS DONE
# ONE BACKWARD PASS DONE
#  60%|██████████████████████████▍                 | 9/15 [00:06<00:04,  1.27it/s]At Epoch 2:
# generating rows
#
#   0%|                                                    | 0/20 [00:00<?, ?it/s]
# 100%|██████████████████████████████████████████| 20/20 [00:00<00:00, 141.53it/s]
# generating rows
#
#   0%|                                                    | 0/20 [00:00<?, ?it/s]
# 100%|██████████████████████████████████████████| 20/20 [00:00<00:00, 107.26it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  20
# new size:  40
# generating rows
#
# 100%|█████████████████████████████████████████████| 7/7 [00:00<00:00, 79.14it/s]
# generating rows
#
# 100%|████████████████████████████████████████████| 7/7 [00:00<00:00, 139.98it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  7
# new size:  14
# ONE FORWARD PASS DONE
# ONE BACKWARD PASS DONE
#  67%|████████████████████████████▋              | 10/15 [00:07<00:04,  1.10it/s]At Epoch 2:
# generating rows
#
# 100%|█████████████████████████████████████████████| 4/4 [00:00<00:00, 78.19it/s]
# generating rows
#
# 100%|█████████████████████████████████████████████| 4/4 [00:00<00:00, 52.63it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  4
# new size:  8
# generating rows
#
# 100%|█████████████████████████████████████████████| 1/1 [00:00<00:00, 76.02it/s]
# generating rows
#
# 100%|████████████████████████████████████████████| 1/1 [00:00<00:00, 407.49it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  1
# new size:  2
# ONE FORWARD PASS DONE
# ONE BACKWARD PASS DONE
#  73%|███████████████████████████████▌           | 11/15 [00:07<00:02,  1.35it/s]At Epoch 2:
# generating rows
#
# 100%|████████████████████████████████████████████| 8/8 [00:00<00:00, 156.38it/s]
# generating rows
#
# 100%|████████████████████████████████████████████| 8/8 [00:00<00:00, 153.39it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  8
# new size:  16
# generating rows
#
# 100%|████████████████████████████████████████████| 3/3 [00:00<00:00, 313.77it/s]
# generating rows
#
# 100%|████████████████████████████████████████████| 3/3 [00:00<00:00, 174.88it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  3
# new size:  6
# ONE FORWARD PASS DONE
# ONE BACKWARD PASS DONE
#  80%|██████████████████████████████████▍        | 12/15 [00:08<00:02,  1.48it/s]At Epoch 2:
# generating rows
#
#   0%|                                                    | 0/12 [00:00<?, ?it/s]
# 100%|███████████████████████████████████████████| 12/12 [00:00<00:00, 90.72it/s]
# generating rows
#
# 100%|██████████████████████████████████████████| 12/12 [00:00<00:00, 147.91it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  12
# new size:  24
# generating rows
#
# 100%|████████████████████████████████████████████| 3/3 [00:00<00:00, 135.70it/s]
# generating rows
#
# 100%|█████████████████████████████████████████████| 3/3 [00:00<00:00, 73.00it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  3
# new size:  6
# ONE FORWARD PASS DONE
# ONE BACKWARD PASS DONE
#  87%|█████████████████████████████████████▎     | 13/15 [00:09<00:01,  1.43it/s]At Epoch 2:
# generating rows
#
#   0%|                                                    | 0/16 [00:00<?, ?it/s]
# 100%|██████████████████████████████████████████| 16/16 [00:00<00:00, 139.67it/s]
# generating rows
#
#   0%|                                                    | 0/16 [00:00<?, ?it/s]
# 100%|██████████████████████████████████████████| 16/16 [00:00<00:00, 130.16it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  16
# new size:  32
# generating rows
#
# 100%|█████████████████████████████████████████████| 5/5 [00:00<00:00, 87.53it/s]
# generating rows
#
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 102.09it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  5
# new size:  10
# ONE FORWARD PASS DONE
# ONE BACKWARD PASS DONE
#  93%|████████████████████████████████████████▏  | 14/15 [00:10<00:00,  1.37it/s]At Epoch 2:
# generating rows
#
#   0%|                                                    | 0/20 [00:00<?, ?it/s]
# 100%|██████████████████████████████████████████| 20/20 [00:00<00:00, 141.73it/s]
# generating rows
#
#   0%|                                                    | 0/20 [00:00<?, ?it/s]
# 100%|██████████████████████████████████████████| 20/20 [00:00<00:00, 126.39it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  20
# new size:  40
# generating rows
#
# 100%|█████████████████████████████████████████████| 5/5 [00:00<00:00, 63.44it/s]
# generating rows
#
# 100%|█████████████████████████████████████████████| 5/5 [00:00<00:00, 85.95it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  5
# new size:  10
# ONE FORWARD PASS DONE
# ONE BACKWARD PASS DONE
# 100%|███████████████████████████████████████████| 15/15 [00:11<00:00,  1.34it/s]
# generating rows
# 100%|█████████████████████████████████████████████| 4/4 [00:00<00:00, 88.19it/s]
# generating rows
# 100%|████████████████████████████████████████████| 4/4 [00:00<00:00, 151.28it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  4
# new size:  8
# generating rows
# 100%|█████████████████████████████████████████████| 1/1 [00:00<00:00, 66.31it/s]
# generating rows
# 100%|████████████████████████████████████████████| 1/1 [00:00<00:00, 135.12it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  1
# new size:  2
# generating rows
# 100%|████████████████████████████████████████████| 8/8 [00:00<00:00, 118.75it/s]
# generating rows
# 100%|████████████████████████████████████████████| 8/8 [00:00<00:00, 133.42it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  8
# new size:  16
# generating rows
# 100%|████████████████████████████████████████████| 3/3 [00:00<00:00, 124.18it/s]
# generating rows
# 100%|█████████████████████████████████████████████| 3/3 [00:00<00:00, 81.46it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  3
# new size:  6
# generating rows
# 100%|██████████████████████████████████████████| 12/12 [00:00<00:00, 126.23it/s]
# generating rows
# 100%|██████████████████████████████████████████| 12/12 [00:00<00:00, 112.24it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  12
# new size:  24
# generating rows
# 100%|████████████████████████████████████████████| 3/3 [00:00<00:00, 247.38it/s]
# generating rows
# 100%|█████████████████████████████████████████████| 3/3 [00:00<00:00, 53.98it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  3
# new size:  6
# generating rows
# 100%|██████████████████████████████████████████| 16/16 [00:00<00:00, 119.32it/s]
# generating rows
# 100%|██████████████████████████████████████████| 16/16 [00:00<00:00, 156.84it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  16
# new size:  32
# generating rows
# 100%|████████████████████████████████████████████| 3/3 [00:00<00:00, 159.08it/s]
# generating rows
# 100%|█████████████████████████████████████████████| 3/3 [00:00<00:00, 59.11it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  3
# new size:  6
# generating rows
# 100%|██████████████████████████████████████████| 20/20 [00:00<00:00, 143.02it/s]
# generating rows
# 100%|██████████████████████████████████████████| 20/20 [00:00<00:00, 129.04it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  20
# new size:  40
# generating rows
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 127.54it/s]
# generating rows
# 100%|█████████████████████████████████████████████| 5/5 [00:00<00:00, 96.10it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  5
# new size:  10
# generating rows
# 100%|█████████████████████████████████████████████| 4/4 [00:00<00:00, 61.93it/s]
# generating rows
# 100%|█████████████████████████████████████████████| 4/4 [00:00<00:00, 61.31it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  4
# new size:  8
# generating rows
# 100%|████████████████████████████████████████████| 1/1 [00:00<00:00, 799.98it/s]
# generating rows
# 100%|████████████████████████████████████████████| 1/1 [00:00<00:00, 248.99it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  1
# new size:  2
# generating rows
# 100%|████████████████████████████████████████████| 8/8 [00:00<00:00, 191.04it/s]
# generating rows
# 100%|████████████████████████████████████████████| 8/8 [00:00<00:00, 115.15it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  8
# new size:  16
# generating rows
# 100%|████████████████████████████████████████████| 3/3 [00:00<00:00, 208.98it/s]
# generating rows
# 100%|████████████████████████████████████████████| 3/3 [00:00<00:00, 109.52it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  3
# new size:  6
# generating rows
# 100%|██████████████████████████████████████████| 12/12 [00:00<00:00, 102.78it/s]
# generating rows
# 100%|██████████████████████████████████████████| 12/12 [00:00<00:00, 116.96it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  12
# new size:  24
# generating rows
# 100%|█████████████████████████████████████████████| 5/5 [00:00<00:00, 61.36it/s]
# generating rows
# 100%|█████████████████████████████████████████████| 5/5 [00:00<00:00, 49.15it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  5
# new size:  10
# generating rows
# 100%|██████████████████████████████████████████| 16/16 [00:00<00:00, 135.73it/s]
# generating rows
# 100%|███████████████████████████████████████████| 16/16 [00:00<00:00, 58.92it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  16
# new size:  32
# generating rows
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 223.61it/s]
# generating rows
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 118.76it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  5
# new size:  10
# generating rows
# 100%|██████████████████████████████████████████| 20/20 [00:00<00:00, 111.76it/s]
# generating rows
# 100%|██████████████████████████████████████████| 20/20 [00:00<00:00, 147.56it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  20
# new size:  40
# generating rows
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 107.49it/s]
# generating rows
# 100%|█████████████████████████████████████████████| 5/5 [00:00<00:00, 67.76it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  5
# new size:  10
# generating rows
# 100%|████████████████████████████████████████████| 4/4 [00:00<00:00, 166.90it/s]
# generating rows
# 100%|████████████████████████████████████████████| 4/4 [00:00<00:00, 135.52it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  4
# new size:  8
# generating rows
# 100%|█████████████████████████████████████████████| 1/1 [00:00<00:00, 43.86it/s]
# generating rows
# 100%|█████████████████████████████████████████████| 1/1 [00:00<00:00, 41.24it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  1
# new size:  2
# generating rows
# 100%|█████████████████████████████████████████████| 8/8 [00:00<00:00, 99.17it/s]
# generating rows
# 100%|████████████████████████████████████████████| 8/8 [00:00<00:00, 121.91it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  8
# new size:  16
# generating rows
# 100%|████████████████████████████████████████████| 3/3 [00:00<00:00, 319.76it/s]
# generating rows
# 100%|████████████████████████████████████████████| 3/3 [00:00<00:00, 109.13it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  3
# new size:  6
# generating rows
# 100%|██████████████████████████████████████████| 12/12 [00:00<00:00, 130.60it/s]
# generating rows
# 100%|██████████████████████████████████████████| 12/12 [00:00<00:00, 165.40it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  12
# new size:  24
# generating rows
# 100%|████████████████████████████████████████████| 4/4 [00:00<00:00, 182.02it/s]
# generating rows
# 100%|████████████████████████████████████████████| 4/4 [00:00<00:00, 284.78it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  4
# new size:  8
# generating rows
# 100%|██████████████████████████████████████████| 16/16 [00:00<00:00, 206.72it/s]
# generating rows
# 100%|██████████████████████████████████████████| 16/16 [00:00<00:00, 120.48it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  16
# new size:  32
# generating rows
# 100%|████████████████████████████████████████████| 4/4 [00:00<00:00, 201.80it/s]
# generating rows
# 100%|█████████████████████████████████████████████| 4/4 [00:00<00:00, 99.71it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  4
# new size:  8
# generating rows
# 100%|██████████████████████████████████████████| 20/20 [00:00<00:00, 145.61it/s]
# generating rows
# 100%|██████████████████████████████████████████| 20/20 [00:00<00:00, 122.09it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  20
# new size:  40
# generating rows
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 155.21it/s]
# generating rows
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 178.56it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  5
# new size:  10
#
#
#                           )                           (           )       (
#  (                     ( /(               )           )\   (   ( /(   (   )\ )
#  )\   `  )    (    (   )\())   (   (     (     `  )  ((_) ))\  )\()) ))\ (()/(
# ((_)  /(/(    )\   )\ ((_)\    )\  )\    )\  ' /(/(   _  /((_)(_))/ /((_) ((_))
# | __|((_)_\  ((_) ((_)| |(_)  ((_)((_) _((_)) ((_)_\ | |(_))  | |_ (_))   _| |
# | _| | '_ \)/ _ \/ _| | ' \  / _|/ _ \| '  \()| '_ \)| |/ -_) |  _|/ -_)/ _` |
# |___|| .__/ \___/\__| |_||_| \__|\___/|_|_|_| | .__/ |_|\___|  \__|\___|\__,_|
#      |_|                                      |_|
#
# Epoch 2:
# 🔥 Training Loss: 0.871632, Validation Loss: 0.871004
#
#
#
#
#
#                           .--.   _..._   .--.   _..._
#                           |__| .'     '. |__| .'     '.   .--./)
#      .|  .-,.--.          .--..   .-.   ..--..   .-.   . /.''\
#    .' |_ |  .-. |    __   |  ||  '   '  ||  ||  '   '  || |  | |
#  .'     || |  | | .:--.'. |  ||  |   |  ||  ||  |   |  | \`-' /
# '--.  .-'| |  | |/ |   \ ||  ||  |   |  ||  ||  |   |  | /("'`
#    |  |  | |  '- `" __ | ||  ||  |   |  ||  ||  |   |  | \ '---.
#    |  |  | |      .'.''| ||__||  |   |  ||__||  |   |  |  /'""'.\
#    |  '.'| |     / /   | |_   |  |   |  |    |  |   |  | ||     ||
#    |   / |_|     \ \._,\ '/   |  |   |  |    |  |   |  | '. __//
#    `'-'           `--'  `"    '--'   '--'    '--'   '--'  `'---'
#        _..._       .-'''-.
#     .-'_..._''.   '   _    \                                         .---.                                                _______
#   .' .'      '.\/   /` '.   \  __  __   ___  _________   _...._      |   |      __.....__                    __.....__    \  ___ `'.
#  / .'          .   |     \  ' |  |/  `.'   `.\        |.'      '-.   |   |  .-''         '.              .-''         '.   ' |--.\  \
# . '            |   '      |  '|   .-.  .-.   '\        .'```'.    '. |   | /     .-''"'-.  `.      .|   /     .-''"'-.  `. | |    \  '
# | |            \    \     / / |  |  |  |  |  | \      |       \     \|   |/     /________\   \   .' |_ /     /________\   \| |     |  '
# | |             `.   ` ..' /  |  |  |  |  |  |  |     |        |    ||   ||                  | .'     ||                  || |     |  |
# . '                '-...-'`   |  |  |  |  |  |  |      \      /    . |   |\    .-------------''--.  .-'\    .-------------'| |     ' .'
#  \ '.          .              |  |  |  |  |  |  |     |\`'-.-'   .'  |   | \    '-.____...---.   |  |   \    '-.____...---.| |___.' /'
#   '. `._____.-'/              |__|  |__|  |__|  |     | '-....-'`    |   |  `.             .'    |  |    `.             .'/_______.'/
#     `-.______ /                                .'     '.             '---'    `''-...... -'      |  '.'    `''-...... -'  \_______|/
#              `                               '-----------'                                       |   /
#                                                                                                  `'-'
#
#                                 |_|
#
# Copied ../experiments/damcc_ba_2025-02-24_22-36-02 to ../experiments/last_experiment

# %% [markdown]
# We now test:

# %%
# Run the DAMCC model in test mode using the specified parameters
# --test: flag to indicate test mode
# --data_name: name of the dataset
# --test_file: path to the test data file in CC format
# --test_graphs_file: path to the raw test graphs file
# --model_path: path to the trained model file
# --save_dir: directory where the test results and other outputs will be saved
# !python ../run_damcc.py \
    --test \
    --data_name ba \
    --test_file ../data/processed_datasets/ba/CC_data/ba_test_ccs.pkl \
    --test_graphs_file ../data/processed_datasets/ba/graph_data/ba_test_graphs_raw.pkl \
    --model_path ../experiments/last_experiment/best_val_model.pth \
    --save_dir ../experiments/last_experiment/
# Out:
# Using device: cpu
# /opt/anaconda3/envs/damcc_eval/lib/python3.11/site-packages/topomodelx/nn/combinatorial/hmc_layer.py:680: UserWarning: Sparse CSR tensor support is in beta state. If you miss a functionality in the sparse tensor support, please submit a feature request to https://github.com/pytorch/pytorch/issues. (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/SparseCsrTensorImpl.cpp:56.)
#   A_p = torch.sparse.mm(A_p, neighborhood)
# generating rows
# 100%|████████████████████████████████████████████| 4/4 [00:00<00:00, 284.90it/s]
# generating rows
# 100%|████████████████████████████████████████████| 4/4 [00:00<00:00, 279.11it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  4
# new size:  8
# generating rows
# 100%|████████████████████████████████████████████| 1/1 [00:00<00:00, 751.80it/s]
# generating rows
# 100%|█████████████████████████████████████████████| 1/1 [00:00<00:00, 34.66it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  1
# new size:  2
# generating rows
# 100%|█████████████████████████████████████████████| 8/8 [00:00<00:00, 83.13it/s]
# generating rows
# 100%|████████████████████████████████████████████| 8/8 [00:00<00:00, 132.41it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  8
# new size:  16
# generating rows
# 100%|████████████████████████████████████████████| 3/3 [00:00<00:00, 132.31it/s]
# generating rows
# 100%|█████████████████████████████████████████████| 3/3 [00:00<00:00, 39.67it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  3
# new size:  6
# generating rows
# 100%|███████████████████████████████████████████| 12/12 [00:00<00:00, 44.48it/s]
# generating rows
# 100%|██████████████████████████████████████████| 12/12 [00:00<00:00, 127.21it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  12
# new size:  24
# generating rows
# 100%|████████████████████████████████████████████| 3/3 [00:00<00:00, 309.60it/s]
# generating rows
# 100%|████████████████████████████████████████████| 3/3 [00:00<00:00, 183.60it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  3
# new size:  6
# generating rows
# 100%|██████████████████████████████████████████| 16/16 [00:00<00:00, 170.82it/s]
# generating rows
# 100%|██████████████████████████████████████████| 16/16 [00:00<00:00, 137.58it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  16
# new size:  32
# generating rows
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 125.25it/s]
# generating rows
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 187.90it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  5
# new size:  10
# generating rows
# 100%|██████████████████████████████████████████| 20/20 [00:00<00:00, 139.83it/s]
# generating rows
# 100%|██████████████████████████████████████████| 20/20 [00:00<00:00, 173.37it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  20
# new size:  40
# generating rows
# 100%|█████████████████████████████████████████████| 7/7 [00:00<00:00, 79.49it/s]
# generating rows
# 100%|████████████████████████████████████████████| 7/7 [00:00<00:00, 208.96it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  7
# new size:  14
# generating rows
# 100%|████████████████████████████████████████████| 4/4 [00:00<00:00, 160.71it/s]
# generating rows
# 100%|█████████████████████████████████████████████| 4/4 [00:00<00:00, 96.19it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  4
# new size:  8
# generating rows
# 100%|█████████████████████████████████████████████| 1/1 [00:00<00:00, 93.36it/s]
# generating rows
# 100%|█████████████████████████████████████████████| 1/1 [00:00<00:00, 78.57it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  1
# new size:  2
# generating rows
# 100%|█████████████████████████████████████████████| 8/8 [00:00<00:00, 85.64it/s]
# generating rows
# 100%|████████████████████████████████████████████| 8/8 [00:00<00:00, 128.29it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  8
# new size:  16
# generating rows
# 100%|█████████████████████████████████████████████| 3/3 [00:00<00:00, 76.53it/s]
# generating rows
# 100%|████████████████████████████████████████████| 3/3 [00:00<00:00, 310.43it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  3
# new size:  6
# generating rows
# 100%|██████████████████████████████████████████| 12/12 [00:00<00:00, 197.49it/s]
# generating rows
# 100%|██████████████████████████████████████████| 12/12 [00:00<00:00, 136.69it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  12
# new size:  24
# generating rows
# 100%|████████████████████████████████████████████| 4/4 [00:00<00:00, 363.93it/s]
# generating rows
# 100%|█████████████████████████████████████████████| 4/4 [00:00<00:00, 75.39it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  4
# new size:  8
# generating rows
# 100%|███████████████████████████████████████████| 16/16 [00:00<00:00, 99.90it/s]
# generating rows
# 100%|██████████████████████████████████████████| 16/16 [00:00<00:00, 109.39it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  16
# new size:  32
# generating rows
# 100%|█████████████████████████████████████████████| 5/5 [00:00<00:00, 86.38it/s]
# generating rows
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 193.63it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  5
# new size:  10
# generating rows
# 100%|███████████████████████████████████████████| 20/20 [00:00<00:00, 56.27it/s]
# generating rows
# 100%|███████████████████████████████████████████| 20/20 [00:00<00:00, 86.75it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  20
# new size:  40
# generating rows
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 101.85it/s]
# generating rows
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 140.89it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  5
# new size:  10
# generating rows
# 100%|████████████████████████████████████████████| 4/4 [00:00<00:00, 195.67it/s]
# generating rows
# 100%|████████████████████████████████████████████| 4/4 [00:00<00:00, 148.57it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  4
# new size:  8
# generating rows
# 100%|█████████████████████████████████████████████| 1/1 [00:00<00:00, 45.52it/s]
# generating rows
# 100%|█████████████████████████████████████████████| 1/1 [00:00<00:00, 27.41it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  1
# new size:  2
# generating rows
# 100%|█████████████████████████████████████████████| 8/8 [00:00<00:00, 78.40it/s]
# generating rows
# 100%|████████████████████████████████████████████| 8/8 [00:00<00:00, 103.15it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  8
# new size:  16
# generating rows
# 100%|█████████████████████████████████████████████| 3/3 [00:00<00:00, 65.86it/s]
# generating rows
# 100%|█████████████████████████████████████████████| 3/3 [00:00<00:00, 75.78it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  3
# new size:  6
# generating rows
# 100%|██████████████████████████████████████████| 12/12 [00:00<00:00, 123.77it/s]
# generating rows
# 100%|██████████████████████████████████████████| 12/12 [00:00<00:00, 191.49it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  12
# new size:  24
# generating rows
# 100%|█████████████████████████████████████████████| 6/6 [00:00<00:00, 90.61it/s]
# generating rows
# 100%|████████████████████████████████████████████| 6/6 [00:00<00:00, 143.48it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  6
# new size:  12
# generating rows
# 100%|██████████████████████████████████████████| 16/16 [00:00<00:00, 140.14it/s]
# generating rows
# 100%|██████████████████████████████████████████| 16/16 [00:00<00:00, 101.73it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  16
# new size:  32
# generating rows
# 100%|█████████████████████████████████████████████| 6/6 [00:00<00:00, 68.89it/s]
# generating rows
# 100%|█████████████████████████████████████████████| 6/6 [00:00<00:00, 73.09it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  6
# new size:  12
# generating rows
# 100%|██████████████████████████████████████████| 20/20 [00:00<00:00, 125.14it/s]
# generating rows
# 100%|██████████████████████████████████████████| 20/20 [00:00<00:00, 101.38it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  20
# new size:  40
# generating rows
# 100%|████████████████████████████████████████████| 6/6 [00:00<00:00, 173.98it/s]
# generating rows
# 100%|████████████████████████████████████████████| 6/6 [00:00<00:00, 169.56it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  6
# new size:  12
# generating rows
# 100%|████████████████████████████████████████████| 4/4 [00:00<00:00, 119.99it/s]
# generating rows
# 100%|████████████████████████████████████████████| 4/4 [00:00<00:00, 179.85it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  4
# new size:  8
# generating rows
# 100%|█████████████████████████████████████████████| 1/1 [00:00<00:00, 53.84it/s]
# generating rows
# 100%|█████████████████████████████████████████████| 1/1 [00:00<00:00, 74.03it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  1
# new size:  2
# generating rows
# 100%|█████████████████████████████████████████████| 8/8 [00:00<00:00, 99.65it/s]
# generating rows
# 100%|████████████████████████████████████████████| 8/8 [00:00<00:00, 107.21it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  8
# new size:  16
# generating rows
# 100%|████████████████████████████████████████████| 3/3 [00:00<00:00, 191.75it/s]
# generating rows
# 100%|████████████████████████████████████████████| 3/3 [00:00<00:00, 119.95it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  3
# new size:  6
# generating rows
# 100%|██████████████████████████████████████████| 12/12 [00:00<00:00, 179.82it/s]
# generating rows
# 100%|██████████████████████████████████████████| 12/12 [00:00<00:00, 101.68it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  12
# new size:  24
# generating rows
# 100%|████████████████████████████████████████████| 3/3 [00:00<00:00, 109.28it/s]
# generating rows
# 100%|█████████████████████████████████████████████| 3/3 [00:00<00:00, 97.65it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  3
# new size:  6
# generating rows
# 100%|██████████████████████████████████████████| 16/16 [00:00<00:00, 164.42it/s]
# generating rows
# 100%|██████████████████████████████████████████| 16/16 [00:00<00:00, 135.96it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  16
# new size:  32
# generating rows
# 100%|█████████████████████████████████████████████| 6/6 [00:00<00:00, 78.94it/s]
# generating rows
# 100%|████████████████████████████████████████████| 6/6 [00:00<00:00, 109.67it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  6
# new size:  12
# generating rows
# 100%|██████████████████████████████████████████| 20/20 [00:00<00:00, 130.29it/s]
# generating rows
# 100%|██████████████████████████████████████████| 20/20 [00:00<00:00, 126.19it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  20
# new size:  40
# generating rows
# 100%|█████████████████████████████████████████████| 7/7 [00:00<00:00, 69.85it/s]
# generating rows
# 100%|████████████████████████████████████████████| 7/7 [00:00<00:00, 173.70it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  7
# new size:  14
# generating rows
# 100%|████████████████████████████████████████████| 4/4 [00:00<00:00, 198.33it/s]
# generating rows
# 100%|█████████████████████████████████████████████| 4/4 [00:00<00:00, 25.50it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  4
# new size:  8
# generating rows
# 100%|█████████████████████████████████████████████| 1/1 [00:00<00:00, 38.36it/s]
# generating rows
# 100%|█████████████████████████████████████████████| 1/1 [00:00<00:00, 59.12it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  1
# new size:  2
# generating rows
# 100%|████████████████████████████████████████████| 8/8 [00:00<00:00, 141.10it/s]
# generating rows
# 100%|█████████████████████████████████████████████| 8/8 [00:00<00:00, 85.22it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  8
# new size:  16
# generating rows
# 100%|████████████████████████████████████████████| 3/3 [00:00<00:00, 126.21it/s]
# generating rows
# 100%|████████████████████████████████████████████| 3/3 [00:00<00:00, 374.77it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  3
# new size:  6
# generating rows
# 100%|███████████████████████████████████████████| 12/12 [00:00<00:00, 94.60it/s]
# generating rows
# 100%|██████████████████████████████████████████| 12/12 [00:00<00:00, 170.08it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  12
# new size:  24
# generating rows
# 100%|████████████████████████████████████████████| 4/4 [00:00<00:00, 237.77it/s]
# generating rows
# 100%|████████████████████████████████████████████| 4/4 [00:00<00:00, 146.82it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  4
# new size:  8
# generating rows
# 100%|██████████████████████████████████████████| 16/16 [00:00<00:00, 120.09it/s]
# generating rows
# 100%|██████████████████████████████████████████| 16/16 [00:00<00:00, 118.24it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  16
# new size:  32
# generating rows
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 126.85it/s]
# generating rows
# 100%|█████████████████████████████████████████████| 5/5 [00:00<00:00, 70.62it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  5
# new size:  10
# generating rows
# 100%|██████████████████████████████████████████| 20/20 [00:00<00:00, 149.53it/s]
# generating rows
# 100%|██████████████████████████████████████████| 20/20 [00:00<00:00, 146.34it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  20
# new size:  40
# generating rows
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 117.97it/s]
# generating rows
# 100%|█████████████████████████████████████████████| 5/5 [00:00<00:00, 91.50it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  5
# new size:  10
# generating rows
# 100%|████████████████████████████████████████████| 4/4 [00:00<00:00, 155.35it/s]
# generating rows
# 100%|████████████████████████████████████████████| 4/4 [00:00<00:00, 190.15it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  4
# new size:  8
# generating rows
# 100%|████████████████████████████████████████████| 1/1 [00:00<00:00, 487.82it/s]
# generating rows
# 100%|████████████████████████████████████████████| 1/1 [00:00<00:00, 156.81it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  1
# new size:  2
# generating rows
# 100%|████████████████████████████████████████████| 8/8 [00:00<00:00, 202.51it/s]
# generating rows
# 100%|████████████████████████████████████████████| 8/8 [00:00<00:00, 154.03it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  8
# new size:  16
# generating rows
# 100%|████████████████████████████████████████████| 3/3 [00:00<00:00, 193.52it/s]
# generating rows
# 100%|████████████████████████████████████████████| 3/3 [00:00<00:00, 309.76it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  3
# new size:  6
# generating rows
# 100%|██████████████████████████████████████████| 12/12 [00:00<00:00, 116.21it/s]
# generating rows
# 100%|██████████████████████████████████████████| 12/12 [00:00<00:00, 122.01it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  12
# new size:  24
# generating rows
# 100%|████████████████████████████████████████████| 3/3 [00:00<00:00, 175.63it/s]
# generating rows
# 100%|████████████████████████████████████████████| 3/3 [00:00<00:00, 148.77it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  3
# new size:  6
# generating rows
# 100%|██████████████████████████████████████████| 16/16 [00:00<00:00, 113.98it/s]
# generating rows
# 100%|██████████████████████████████████████████| 16/16 [00:00<00:00, 153.77it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  16
# new size:  32
# generating rows
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 133.57it/s]
# generating rows
# 100%|█████████████████████████████████████████████| 5/5 [00:00<00:00, 97.48it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  5
# new size:  10
# generating rows
# 100%|██████████████████████████████████████████| 20/20 [00:00<00:00, 159.00it/s]
# generating rows
# 100%|██████████████████████████████████████████| 20/20 [00:00<00:00, 149.51it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  20
# new size:  40
# generating rows
# 100%|████████████████████████████████████████████| 7/7 [00:00<00:00, 123.42it/s]
# generating rows
# 100%|████████████████████████████████████████████| 7/7 [00:00<00:00, 121.45it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  7
# new size:  14
#
#    ■  ▗▞▀▚▖ ▄▄▄  ■         ▐▌▗▞▀▜▌   ■  ▗▞▀▜▌     ▄▄▄ ▗▞▀▜▌▄   ▄ ▗▞▀▚▖   ▐▌
# ▗▄▟▙▄▖▐▛▀▀▘▀▄▄▗▄▟▙▄▖       ▐▌▝▚▄▟▌▗▄▟▙▄▖▝▚▄▟▌    ▀▄▄  ▝▚▄▟▌█   █ ▐▛▀▀▘   ▐▌
#   ▐▌  ▝▚▄▄▖▄▄▄▀ ▐▌      ▗▞▀▜▌       ▐▌           ▄▄▄▀       ▀▄▀  ▝▚▄▄▖▗▞▀▜▌
#   ▐▌            ▐▌      ▝▚▄▟▌       ▐▌                                ▝▚▄▟▌
#   ▐▌            ▐▌                  ▐▌
#
#
# Test results saved to ../experiments/last_experiment/test

# %% [markdown]
# Let us see what the Sampled graphs look like:

# %%
# Open the file containing the generated data and load it using pickle
with open('../experiments/last_experiment/test/sampled_graphs.pkl', 'rb') as file:
    generated_data = pickle.load(file)

# Create a figure with subplots for each graph in the first sequence of generated data
fig, axes = plt.subplots(2, len(generated_data[0]) // 2, figsize=(20, 11))
axes = axes.flatten()  # Flatten the 2D array of axes

# Iterate over each graph in the first sequence of generated data and plot it
for i, graph in enumerate(generated_data[0]):
    ax = axes[i]
    nx.draw(graph, pos, with_labels=True, node_color='skyblue', node_size=250, edge_color='gray', 
            font_size=10, font_color='black', font_weight='bold', ax=ax)
    ax.set_title(f"Timestep {i+1}")

# Display the plot
plt.show()

# %% [markdown]
# We now evaluate. Note that in the original paper we us ethe evaluation teqchniques introduced in [this link](https://dl.acm.org/doi/10.1145/3642970.3655829). The code for that is not available as teh authors asked it to not be shared. However the evaluation we provide here is from [DAMNETS](https://arxiv.org/abs/2203.15009) and originally available on [github](https://github.com/jase-clarkson/DAMNETS_LoG).

# %%
# !python ../eval.py \
    --sampled_path ../experiments/last_experiment/test/sampled_graphs.pkl \
    --test_path ../data/processed_datasets/ba/graph_data/ba_test_graphs_raw.pkl \
    --dataset_name ba \
    --model_name damcc \
    --output_dir ../eval
# Out:
# Computing statistics for model damcc
# Computing Density
# Computing Clustering
# Computing Transitivity
# Computing Assortativity
# Computing Closeness
# Computing statistics for model Test
# Computing Density
# Computing Clustering
# Computing Transitivity
# Computing Assortativity
# Computing Closeness
# Computing Local MMDs
# 100%|█████████████████████████████████████████████| 5/5 [00:00<00:00, 24.65it/s]
# 100%|█████████████████████████████████████████████| 5/5 [00:00<00:00, 97.93it/s]
# ------ Sum MMDs ------
# damcc  Degree_MMD        1.193602
#        Clustering_MMD    4.556618
#        Spectral_MMD      0.652966
#        Trans_MMD         1.815586
#        Assort_MMD        1.054388
#        CC_MMD            0.721815
# dtype: float64

# %%
import pandas as pd
print(pd.__version__)
# Out:
# 2.2.3

# %%
from IPython.display import Image

# Display the image
Image(filename='../eval/damcc_network_statistics.jpg', width=2000, height=300)

# %%
Image(filename='../eval/damcc_ba_degree.jpg', width=800)

# %% [markdown]
# # DAMCC
#
# The thesis paper is available [here]([URL_TO_PAPER](https://dl.acm.org/doi/10.1145/3642970.3655829)).
#
# ## Problem Statement
#
# **Graphs:** Given a timestamp $t$, we represent each graph in the data as a tuple of its adjacency and node feature matrices:
#
# $$
# G_t = (\mathbf{X}_t, \mathbf{A}_t)
# $$
#
# where
#
# $$
# \mathbf{X}_t \in \mathbb{R}^{N \times F}, \quad \mathbf{A}_t \in \{0,1\}^{N \times N}
# $$
#
# Here, $N$ is the total number of nodes, and $F$ is the number of node features. We then represent a graph time series as a sequence of graphs over time:
#
# $$
# (G_t)_{t=0}^T = (G_1, G_2, \dots, G_T)
# $$
#
# where $T$ is the last timestamp. For our synthetically generated datasets, we have more than one such sequence of graphs. Therefore, we represent the full dataset as a set of graph sequences:
#
# $$
# \{(G_t^1)_{t=0}^T, (G_t^2)_{t=0}^T, \dots, (G_t^{L-1})_{t=0}^T, (G_t^L)_{t=0}^T \}
# $$
#
# Given an unseen graph $G_t$ from such a dataset, our task is to predict $G_{t+1}$.

# %%
import pickle
import networkx as nx
import matplotlib.pyplot as plt
import os
import sys
import pandas as pd

# Add the parent directory of utils to the Python path
sys.path.append(os.path.join(os.getcwd(), '..'))
# from utils.utils import display_data_nice

# %% [markdown]
# First, let us create the dataset. Let us generate a dataset based on the Barabási–Albert (BA) model. BA is a widely used algorithm in network science for generating scale-free networks, which are characterized by a power-law degree distribution. See [wikipedia]([URL_TO_PAPER](https://en.wikipedia.org/wiki/Barab%C3%A1si%E2%80%93Albert_model))
#  for more details. For us, it suffices us to know that this is some non-random sequence of graphs. We generate a BA dataset via a yaml config file in the data directory. Lets use the ba.yaml as an example.

# %%
# Generate data using the specified YAML configuration file
# -c: path to the configuration file
# -p: path to the directory where the generated data will be saved
# -d: name of the dataset
# !python ../data/generate_data.py \
    -c ../data/data_configs/ba.yaml \
    -p ../data/datasets \
    -d ba
# Out:
# 100%|███████████████████████████████████████████| 12/12 [00:02<00:00,  4.24it/s]
# 12

# %% [markdown]
# This process yields a list of 12 graph sequences with 6 graphs in each sequence each of which is a networkx.Graph object. Let us now see what this generated data looks like. Let us use the first sequence out of the three.

# %%
# Open the dataset file and load the data using pickle
with open('../data/datasets/ba.pkl', 'rb') as file:
    data = pickle.load(file)

# Set up the positions for the nodes for plotting using spring layout
# Use a fixed seed for reproducibility
graph = data[0][-1]
pos = nx.spring_layout(graph, seed=4)  
pos[2] = [0.1, -0.5]  # Manually adjust the position of node 2

# Plot the first graph in the data list
fig, axes = plt.subplots(2, len(data[0]) // 2, figsize=(20, 11))
axes = axes.flatten()  # Flatten the 2D array of axes

# Iterate over each graph in the first sequence and plot it
for i, graph in enumerate(data[0]):
    ax = axes[i]
    nx.draw(graph, pos, with_labels=True, node_color='skyblue', node_size=250, edge_color='gray', 
            font_size=10, font_color='black', font_weight='bold', ax=ax)
    ax.set_title(f"Timestep {i+1}")

# Display the plot
plt.show()

# %% [markdown]
# Then, we need to preprocess to separate to train, validate , and test:

# %%
# Preprocess the data using the specified dataset file
# -d: path to the dataset file
# -s: path to the directory where the processed data will be saved
# -t: proportion of the data to be used for training
# -v: proportion of the data to be used for validation
# -r: whether to shuffle the data (False means no shuffling)
# !python ../data/preprocess_data.py \
    -d ../data/datasets/ba.pkl \
    -s ../data/processed_datasets/ba/graph_data/ \
    -t 0.5 \
    -v 0.5 \
    -r False
# Out:
# Randomizing
# Number of Training TS:  3
# Number of Val TS:  3
# Number of Test TS:  6
# TS length (T):  6
# Saving Graphs
# 6
# 6
# 6
# Computing Deltas
# Converting to networkx format
# 100%|██████████████████████████████████████████| 15/15 [00:00<00:00, 565.00it/s]
# Setting attributes.
# 100%|███████████████████████████████████████| 15/15 [00:00<00:00, 120989.54it/s]
# Computing Deltas
# Converting to networkx format
# 100%|█████████████████████████████████████████| 15/15 [00:00<00:00, 2780.75it/s]
# Setting attributes.
# 100%|████████████████████████████████████████| 15/15 [00:00<00:00, 64660.39it/s]

# %% [markdown]
# You should now have the following files in the data directory:
# ba_test_graphs_raw.pkl  ba_train_graphs.pkl  ba_train_graphs_raw.pkl  ba_val_graphs.pkl  ba_val_graphs_raw.pkl. The files with no -raw suffix are for DAMNETS and AGE models. Let us now see processed format of our data:

# %%
# The non-raw datasets are for the DAMNETS model
# Load the training dataset
with open('../data/processed_datasets/ba/graph_data/ba_train_graphs_raw.pkl', 'rb') as file:
    train_data = pickle.load(file)

# Load the validation dataset
with open('../data/processed_datasets/ba/graph_data/ba_val_graphs_raw.pkl', 'rb') as file:
    val_data = pickle.load(file)

# Load the test dataset
with open('../data/processed_datasets/ba/graph_data/ba_test_graphs_raw.pkl', 'rb') as file:
    test_data = pickle.load(file)

# Combine the datasets into a list for easier iteration
datasets = [train_data, val_data, test_data]
dataset_names = ['Train', 'Validation', 'Test']

# Iterate over each dataset and plot the graphs
for dataset, name in zip(datasets, dataset_names):
    # Create a figure with subplots for each graph in the dataset
    fig, axes = plt.subplots(1, len(dataset[0]), figsize=(20, 3))
    axes = axes.flatten()  # Flatten the 2D array of axes

    # Iterate over each graph in the dataset and plot it
    for i, graph in enumerate(dataset[0]):
        ax = axes[i]
        nx.draw(graph, pos, with_labels=True, node_color='skyblue', node_size=250, edge_color='gray', 
                font_size=10, font_color='black', font_weight='bold', ax=ax)
        ax.set_title(f"Timestep {i+1}")

    # Set the title for the entire figure
    fig.suptitle(f"{name} Dataset", fontsize=16)
    plt.show()

# %% [markdown]
# All looks in order. Let us now convert these graphs to CC format:

# %%
# Lift the training graphs to CC format and save the output
# !python ../utils/process_graph_to_cc.py -i ../data/processed_datasets/ba/graph_data/ba_train_graphs_raw.pkl -o ../data/processed_datasets/ba/CC_data

# Lift the validation graphs to CC format and save the output
# !python ../utils/process_graph_to_cc.py -i ../data/processed_datasets/ba/graph_data/ba_val_graphs_raw.pkl -o ../data/processed_datasets/ba/CC_data

# Lift the test graphs to CC format and save the output
# !python ../utils/process_graph_to_cc.py -i ../data/processed_datasets/ba/graph_data/ba_test_graphs_raw.pkl -o ../data/processed_datasets/ba/CC_data
# Out:
# Converting graphs to ccs
# 100%|████████████████████████████████████████████| 6/6 [00:00<00:00, 255.42it/s]
# Converting graphs to ccs
# 100%|████████████████████████████████████████████| 6/6 [00:00<00:00, 121.40it/s]
# Converting graphs to ccs
# 100%|████████████████████████████████████████████| 6/6 [00:00<00:00, 222.28it/s]
# Setting x_0
# 100%|██████████████████████████████████████████| 6/6 [00:00<00:00, 31575.69it/s]
# Setting x_0
# 100%|██████████████████████████████████████████| 6/6 [00:00<00:00, 58119.69it/s]
# Setting x_0
# 100%|██████████████████████████████████████████| 6/6 [00:00<00:00, 80145.94it/s]
# 100%|████████████████████████████████████████████| 6/6 [00:00<00:00, 595.23it/s]
# 100%|███████████████████████████████████████████| 6/6 [00:00<00:00, 3848.57it/s]
# 100%|███████████████████████████████████████████| 6/6 [00:00<00:00, 2714.76it/s]
# Data saved to ../data/processed_datasets/ba/CC_data/ba_train_ccs.pkl
# Converting graphs to ccs
# 100%|████████████████████████████████████████████| 6/6 [00:00<00:00, 409.08it/s]
# Converting graphs to ccs
# 100%|████████████████████████████████████████████| 6/6 [00:00<00:00, 272.53it/s]
# Converting graphs to ccs
# 100%|████████████████████████████████████████████| 6/6 [00:00<00:00, 440.72it/s]
# Setting x_0
# 100%|███████████████████████████████████████████| 6/6 [00:00<00:00, 8759.42it/s]
# Setting x_0
# 100%|██████████████████████████████████████████| 6/6 [00:00<00:00, 61230.72it/s]
# Setting x_0
# 100%|██████████████████████████████████████████| 6/6 [00:00<00:00, 80145.94it/s]
# 100%|███████████████████████████████████████████| 6/6 [00:00<00:00, 4450.98it/s]
# 100%|███████████████████████████████████████████| 6/6 [00:00<00:00, 5356.71it/s]
# 100%|███████████████████████████████████████████| 6/6 [00:00<00:00, 5339.66it/s]
# Data saved to ../data/processed_datasets/ba/CC_data/ba_val_ccs.pkl
# Converting graphs to ccs
# 100%|████████████████████████████████████████████| 6/6 [00:00<00:00, 249.44it/s]
# Converting graphs to ccs
# 100%|█████████████████████████████████████████████| 6/6 [00:00<00:00, 96.12it/s]
# Converting graphs to ccs
# 100%|█████████████████████████████████████████████| 6/6 [00:00<00:00, 27.51it/s]
# Converting graphs to ccs
# 100%|█████████████████████████████████████████████| 6/6 [00:00<00:00, 86.17it/s]
# Converting graphs to ccs
# 100%|█████████████████████████████████████████████| 6/6 [00:00<00:00, 70.62it/s]
# Converting graphs to ccs
# 100%|████████████████████████████████████████████| 6/6 [00:00<00:00, 281.71it/s]
# Setting x_0
# 100%|██████████████████████████████████████████| 6/6 [00:00<00:00, 25191.02it/s]
# Setting x_0
# 100%|██████████████████████████████████████████| 6/6 [00:00<00:00, 37957.50it/s]
# Setting x_0
# 100%|██████████████████████████████████████████| 6/6 [00:00<00:00, 38776.31it/s]
# Setting x_0
# 100%|██████████████████████████████████████████| 6/6 [00:00<00:00, 14571.99it/s]
# Setting x_0
# 100%|██████████████████████████████████████████| 6/6 [00:00<00:00, 65365.78it/s]
# Setting x_0
# 100%|██████████████████████████████████████████| 6/6 [00:00<00:00, 77912.77it/s]
# 100%|███████████████████████████████████████████| 6/6 [00:00<00:00, 4316.61it/s]
# 100%|███████████████████████████████████████████| 6/6 [00:00<00:00, 5276.96it/s]
# 100%|███████████████████████████████████████████| 6/6 [00:00<00:00, 1646.01it/s]
# 100%|███████████████████████████████████████████| 6/6 [00:00<00:00, 4608.28it/s]
# 100%|███████████████████████████████████████████| 6/6 [00:00<00:00, 1419.07it/s]
# 100%|███████████████████████████████████████████| 6/6 [00:00<00:00, 3177.90it/s]
# Data saved to ../data/processed_datasets/ba/CC_data/ba_test_ccs.pkl

# %% [markdown]
# Its is difficult to visualise CC's so we won't. We now train the model:

# %%
# Train the DAMCC model using the specified parameters
# --train: flag to indicate training mode
# --data_name: name of the dataset
# --train_file: path to the training data file in CC format
# --val_file: path to the validation data file in CC format
# --save_dir: directory where the trained model and other outputs will be saved
# --max_epochs: maximum number of training epochs
# --lr: learning rate for the optimizer
# !python ../run_damcc.py \
    --train \
    --data_name ba \
    --train_file ../data/processed_datasets/ba/CC_data/ba_train_ccs.pkl \
    --val_file ../data/processed_datasets/ba/CC_data/ba_val_ccs.pkl \
    --save_dir ../experiments \
    --max_epochs 2 \
    --lr 0.001
# Out:
# Using device: cpu
#   0%|                                                    | 0/15 [00:00<?, ?it/s]At Epoch 1:
# /opt/anaconda3/envs/damcc_eval/lib/python3.11/site-packages/topomodelx/nn/combinatorial/hmc_layer.py:680: UserWarning: Sparse CSR tensor support is in beta state. If you miss a functionality in the sparse tensor support, please submit a feature request to https://github.com/pytorch/pytorch/issues. (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/SparseCsrTensorImpl.cpp:56.)
#   A_p = torch.sparse.mm(A_p, neighborhood)
# generating rows
#
# 100%|█████████████████████████████████████████████| 4/4 [00:00<00:00, 47.42it/s]
# generating rows
#
# 100%|████████████████████████████████████████████| 4/4 [00:00<00:00, 199.70it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  4
# new size:  8
# generating rows
#
# 100%|████████████████████████████████████████████| 1/1 [00:00<00:00, 351.49it/s]
# generating rows
#
# 100%|████████████████████████████████████████████| 1/1 [00:00<00:00, 291.74it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  1
# new size:  2
# ONE FORWARD PASS DONE
# ONE BACKWARD PASS DONE
#   7%|██▉                                         | 1/15 [00:00<00:07,  1.94it/s]At Epoch 1:
# generating rows
#
# 100%|█████████████████████████████████████████████| 8/8 [00:00<00:00, 90.57it/s]
# generating rows
#
#   0%|                                                     | 0/8 [00:00<?, ?it/s]
# 100%|█████████████████████████████████████████████| 8/8 [00:00<00:00, 68.94it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  8
# new size:  16
# generating rows
#
# 100%|████████████████████████████████████████████| 3/3 [00:00<00:00, 162.30it/s]
# generating rows
#
# 100%|████████████████████████████████████████████| 3/3 [00:00<00:00, 184.72it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  3
# new size:  6
# ONE FORWARD PASS DONE
# ONE BACKWARD PASS DONE
#  13%|█████▊                                      | 2/15 [00:01<00:08,  1.50it/s]At Epoch 1:
# generating rows
#
#   0%|                                                    | 0/12 [00:00<?, ?it/s]
# 100%|███████████████████████████████████████████| 12/12 [00:00<00:00, 94.22it/s]
# generating rows
#
#   0%|                                                    | 0/12 [00:00<?, ?it/s]
# 100%|███████████████████████████████████████████| 12/12 [00:00<00:00, 87.04it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  12
# new size:  24
# generating rows
#
# 100%|█████████████████████████████████████████████| 3/3 [00:00<00:00, 52.91it/s]
# generating rows
#
# 100%|████████████████████████████████████████████| 3/3 [00:00<00:00, 164.02it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  3
# new size:  6
# ONE FORWARD PASS DONE
# ONE BACKWARD PASS DONE
#  20%|████████▊                                   | 3/15 [00:02<00:08,  1.34it/s]At Epoch 1:
# generating rows
#
#   0%|                                                    | 0/16 [00:00<?, ?it/s]
# 100%|███████████████████████████████████████████| 16/16 [00:00<00:00, 88.52it/s]
# generating rows
#
#   0%|                                                    | 0/16 [00:00<?, ?it/s]
# 100%|██████████████████████████████████████████| 16/16 [00:00<00:00, 110.47it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  16
# new size:  32
# generating rows
#
#   0%|                                                     | 0/5 [00:00<?, ?it/s]
# 100%|█████████████████████████████████████████████| 5/5 [00:00<00:00, 49.19it/s]
# generating rows
#
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 112.16it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  5
# new size:  10
# ONE FORWARD PASS DONE
# ONE BACKWARD PASS DONE
#  27%|███████████▋                                | 4/15 [00:03<00:10,  1.05it/s]At Epoch 1:
# generating rows
#
#   0%|                                                    | 0/20 [00:00<?, ?it/s]
#  35%|███████████████▍                            | 7/20 [00:00<00:00, 66.44it/s]
# 100%|███████████████████████████████████████████| 20/20 [00:00<00:00, 74.13it/s]
# generating rows
#
#   0%|                                                    | 0/20 [00:00<?, ?it/s]
#  35%|███████████████▍                            | 7/20 [00:00<00:00, 66.74it/s]
# 100%|███████████████████████████████████████████| 20/20 [00:00<00:00, 80.50it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  20
# new size:  40
# generating rows
#
#   0%|                                                     | 0/7 [00:00<?, ?it/s]
# 100%|█████████████████████████████████████████████| 7/7 [00:00<00:00, 45.95it/s]
# generating rows
#
# 100%|█████████████████████████████████████████████| 7/7 [00:00<00:00, 77.60it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  7
# new size:  14
# ONE FORWARD PASS DONE
# ONE BACKWARD PASS DONE
#  33%|██████████████▋                             | 5/15 [00:06<00:16,  1.60s/it]At Epoch 1:
# generating rows
#
# 100%|████████████████████████████████████████████| 4/4 [00:00<00:00, 138.05it/s]
# generating rows
#
# 100%|█████████████████████████████████████████████| 4/4 [00:00<00:00, 49.14it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  4
# new size:  8
# generating rows
#
# 100%|█████████████████████████████████████████████| 1/1 [00:00<00:00, 60.89it/s]
# generating rows
#
# 100%|█████████████████████████████████████████████| 1/1 [00:00<00:00, 51.22it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  1
# new size:  2
# ONE FORWARD PASS DONE
# ONE BACKWARD PASS DONE
#  40%|█████████████████▌                          | 6/15 [00:06<00:10,  1.19s/it]At Epoch 1:
# generating rows
#
# 100%|█████████████████████████████████████████████| 8/8 [00:00<00:00, 91.24it/s]
# generating rows
#
#   0%|                                                     | 0/8 [00:00<?, ?it/s]
# 100%|█████████████████████████████████████████████| 8/8 [00:00<00:00, 73.79it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  8
# new size:  16
# generating rows
#
#   0%|                                                     | 0/3 [00:00<?, ?it/s]
# 100%|█████████████████████████████████████████████| 3/3 [00:00<00:00, 27.76it/s]
# generating rows
#
# 100%|█████████████████████████████████████████████| 3/3 [00:00<00:00, 55.15it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  3
# new size:  6
# ONE FORWARD PASS DONE
# ONE BACKWARD PASS DONE
#  47%|████████████████████▌                       | 7/15 [00:07<00:08,  1.07s/it]At Epoch 1:
# generating rows
#
#   0%|                                                    | 0/12 [00:00<?, ?it/s]
#  33%|██████████████▋                             | 4/12 [00:00<00:00, 34.83it/s]
# 100%|███████████████████████████████████████████| 12/12 [00:00<00:00, 44.92it/s]
# generating rows
#
#   0%|                                                    | 0/12 [00:00<?, ?it/s]
# 100%|███████████████████████████████████████████| 12/12 [00:00<00:00, 90.12it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  12
# new size:  24
# generating rows
#
# 100%|████████████████████████████████████████████| 3/3 [00:00<00:00, 114.13it/s]
# generating rows
#
# 100%|█████████████████████████████████████████████| 3/3 [00:00<00:00, 56.78it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  3
# new size:  6
# ONE FORWARD PASS DONE
# ONE BACKWARD PASS DONE
#  53%|███████████████████████▍                    | 8/15 [00:08<00:07,  1.08s/it]At Epoch 1:
# generating rows
#
#   0%|                                                    | 0/16 [00:00<?, ?it/s]
#  25%|███████████                                 | 4/16 [00:00<00:00, 39.39it/s]
# 100%|███████████████████████████████████████████| 16/16 [00:00<00:00, 76.56it/s]
# generating rows
#
#   0%|                                                    | 0/16 [00:00<?, ?it/s]
#  44%|███████████████████▎                        | 7/16 [00:00<00:00, 58.71it/s]
# 100%|███████████████████████████████████████████| 16/16 [00:00<00:00, 57.64it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  16
# new size:  32
# generating rows
#
# 100%|█████████████████████████████████████████████| 6/6 [00:00<00:00, 65.55it/s]
# generating rows
#
#   0%|                                                     | 0/6 [00:00<?, ?it/s]
# 100%|█████████████████████████████████████████████| 6/6 [00:00<00:00, 40.15it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  6
# new size:  12
# ONE FORWARD PASS DONE
# ONE BACKWARD PASS DONE
#  60%|██████████████████████████▍                 | 9/15 [00:10<00:07,  1.28s/it]At Epoch 1:
# generating rows
#
#   0%|                                                    | 0/20 [00:00<?, ?it/s]
#  10%|████▍                                       | 2/20 [00:00<00:02,  8.40it/s]
#  15%|██████▌                                     | 3/20 [00:00<00:01,  8.91it/s]
#  25%|███████████                                 | 5/20 [00:00<00:01, 12.59it/s]
#  45%|███████████████████▊                        | 9/20 [00:00<00:00, 19.56it/s]
# 100%|███████████████████████████████████████████| 20/20 [00:00<00:00, 27.78it/s]
# generating rows
#
#   0%|                                                    | 0/20 [00:00<?, ?it/s]
# 100%|███████████████████████████████████████████| 20/20 [00:00<00:00, 89.80it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  20
# new size:  40
# generating rows
#
# 100%|█████████████████████████████████████████████| 7/7 [00:00<00:00, 90.64it/s]
# generating rows
#
#   0%|                                                     | 0/7 [00:00<?, ?it/s]
# 100%|█████████████████████████████████████████████| 7/7 [00:00<00:00, 66.06it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  7
# new size:  14
# ONE FORWARD PASS DONE
# ONE BACKWARD PASS DONE
#  67%|████████████████████████████▋              | 10/15 [00:12<00:07,  1.52s/it]At Epoch 1:
# generating rows
#
# 100%|█████████████████████████████████████████████| 4/4 [00:00<00:00, 51.01it/s]
# generating rows
#
# 100%|████████████████████████████████████████████| 4/4 [00:00<00:00, 112.20it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  4
# new size:  8
# generating rows
#
# 100%|█████████████████████████████████████████████| 1/1 [00:00<00:00, 46.91it/s]
# generating rows
#
# 100%|█████████████████████████████████████████████| 1/1 [00:00<00:00, 24.92it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  1
# new size:  2
# ONE FORWARD PASS DONE
# ONE BACKWARD PASS DONE
#  73%|███████████████████████████████▌           | 11/15 [00:12<00:04,  1.19s/it]At Epoch 1:
# generating rows
#
# 100%|█████████████████████████████████████████████| 8/8 [00:00<00:00, 86.55it/s]
# generating rows
#
# 100%|████████████████████████████████████████████| 8/8 [00:00<00:00, 106.30it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  8
# new size:  16
# generating rows
#
# 100%|████████████████████████████████████████████| 3/3 [00:00<00:00, 116.46it/s]
# generating rows
#
# 100%|█████████████████████████████████████████████| 3/3 [00:00<00:00, 70.63it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  3
# new size:  6
# ONE FORWARD PASS DONE
# ONE BACKWARD PASS DONE
#  80%|██████████████████████████████████▍        | 12/15 [00:13<00:03,  1.01s/it]At Epoch 1:
# generating rows
#
#   0%|                                                    | 0/12 [00:00<?, ?it/s]
# 100%|███████████████████████████████████████████| 12/12 [00:00<00:00, 73.59it/s]
# generating rows
#
#   0%|                                                    | 0/12 [00:00<?, ?it/s]
# 100%|██████████████████████████████████████████| 12/12 [00:00<00:00, 111.65it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  12
# new size:  24
# generating rows
#
# 100%|█████████████████████████████████████████████| 3/3 [00:00<00:00, 48.34it/s]
# generating rows
#
# 100%|█████████████████████████████████████████████| 3/3 [00:00<00:00, 59.84it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  3
# new size:  6
# ONE FORWARD PASS DONE
# ONE BACKWARD PASS DONE
#  87%|█████████████████████████████████████▎     | 13/15 [00:14<00:01,  1.06it/s]At Epoch 1:
# generating rows
#
#   0%|                                                    | 0/16 [00:00<?, ?it/s]
# 100%|███████████████████████████████████████████| 16/16 [00:00<00:00, 85.17it/s]
# generating rows
#
#   0%|                                                    | 0/16 [00:00<?, ?it/s]
# 100%|███████████████████████████████████████████| 16/16 [00:00<00:00, 83.31it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  16
# new size:  32
# generating rows
#
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 105.87it/s]
# generating rows
#
#   0%|                                                     | 0/5 [00:00<?, ?it/s]
# 100%|█████████████████████████████████████████████| 5/5 [00:00<00:00, 32.14it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  5
# new size:  10
# ONE FORWARD PASS DONE
# ONE BACKWARD PASS DONE
#  93%|████████████████████████████████████████▏  | 14/15 [00:15<00:01,  1.05s/it]At Epoch 1:
# generating rows
#
#   0%|                                                    | 0/20 [00:00<?, ?it/s]
# 100%|██████████████████████████████████████████| 20/20 [00:00<00:00, 106.80it/s]
# generating rows
#
#   0%|                                                    | 0/20 [00:00<?, ?it/s]
#  45%|███████████████████▊                        | 9/20 [00:00<00:00, 88.90it/s]
# 100%|███████████████████████████████████████████| 20/20 [00:00<00:00, 97.10it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  20
# new size:  40
# generating rows
#
# 100%|█████████████████████████████████████████████| 7/7 [00:00<00:00, 89.57it/s]
# generating rows
#
#   0%|                                                     | 0/7 [00:00<?, ?it/s]
# 100%|█████████████████████████████████████████████| 7/7 [00:00<00:00, 59.51it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  7
# new size:  14
# ONE FORWARD PASS DONE
# ONE BACKWARD PASS DONE
# 100%|███████████████████████████████████████████| 15/15 [00:16<00:00,  1.12s/it]
# generating rows
# 100%|████████████████████████████████████████████| 4/4 [00:00<00:00, 121.57it/s]
# generating rows
# 100%|█████████████████████████████████████████████| 4/4 [00:00<00:00, 57.14it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  4
# new size:  8
# generating rows
# 100%|█████████████████████████████████████████████| 1/1 [00:00<00:00, 66.68it/s]
# generating rows
# 100%|████████████████████████████████████████████| 1/1 [00:00<00:00, 118.40it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  1
# new size:  2
# generating rows
# 100%|████████████████████████████████████████████| 8/8 [00:00<00:00, 105.02it/s]
# generating rows
# 100%|████████████████████████████████████████████| 8/8 [00:00<00:00, 106.16it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  8
# new size:  16
# generating rows
# 100%|█████████████████████████████████████████████| 3/3 [00:00<00:00, 56.78it/s]
# generating rows
# 100%|████████████████████████████████████████████| 3/3 [00:00<00:00, 131.90it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  3
# new size:  6
# generating rows
# 100%|██████████████████████████████████████████| 12/12 [00:00<00:00, 107.82it/s]
# generating rows
# 100%|███████████████████████████████████████████| 12/12 [00:00<00:00, 98.55it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  12
# new size:  24
# generating rows
# 100%|█████████████████████████████████████████████| 3/3 [00:00<00:00, 90.92it/s]
# generating rows
# 100%|████████████████████████████████████████████| 3/3 [00:00<00:00, 146.91it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  3
# new size:  6
# generating rows
# 100%|███████████████████████████████████████████| 16/16 [00:00<00:00, 93.67it/s]
# generating rows
# 100%|██████████████████████████████████████████| 16/16 [00:00<00:00, 153.77it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  16
# new size:  32
# generating rows
# 100%|█████████████████████████████████████████████| 5/5 [00:00<00:00, 62.92it/s]
# generating rows
# 100%|█████████████████████████████████████████████| 5/5 [00:00<00:00, 42.95it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  5
# new size:  10
# generating rows
# 100%|███████████████████████████████████████████| 20/20 [00:00<00:00, 99.07it/s]
# generating rows
# 100%|██████████████████████████████████████████| 20/20 [00:00<00:00, 116.65it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  20
# new size:  40
# generating rows
# 100%|█████████████████████████████████████████████| 7/7 [00:00<00:00, 67.85it/s]
# generating rows
# 100%|████████████████████████████████████████████| 7/7 [00:00<00:00, 217.97it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  7
# new size:  14
# generating rows
# 100%|████████████████████████████████████████████| 4/4 [00:00<00:00, 185.31it/s]
# generating rows
# 100%|████████████████████████████████████████████| 4/4 [00:00<00:00, 137.72it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  4
# new size:  8
# generating rows
# 100%|████████████████████████████████████████████| 1/1 [00:00<00:00, 268.16it/s]
# generating rows
# 100%|█████████████████████████████████████████████| 1/1 [00:00<00:00, 53.09it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  1
# new size:  2
# generating rows
# 100%|████████████████████████████████████████████| 8/8 [00:00<00:00, 111.61it/s]
# generating rows
# 100%|█████████████████████████████████████████████| 8/8 [00:00<00:00, 63.96it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  8
# new size:  16
# generating rows
# 100%|████████████████████████████████████████████| 3/3 [00:00<00:00, 274.50it/s]
# generating rows
# 100%|████████████████████████████████████████████| 3/3 [00:00<00:00, 206.06it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  3
# new size:  6
# generating rows
# 100%|██████████████████████████████████████████| 12/12 [00:00<00:00, 106.49it/s]
# generating rows
# 100%|██████████████████████████████████████████| 12/12 [00:00<00:00, 103.95it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  12
# new size:  24
# generating rows
# 100%|█████████████████████████████████████████████| 4/4 [00:00<00:00, 96.12it/s]
# generating rows
# 100%|█████████████████████████████████████████████| 4/4 [00:00<00:00, 53.31it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  4
# new size:  8
# generating rows
# 100%|██████████████████████████████████████████| 16/16 [00:00<00:00, 118.85it/s]
# generating rows
# 100%|██████████████████████████████████████████| 16/16 [00:00<00:00, 119.64it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  16
# new size:  32
# generating rows
# 100%|█████████████████████████████████████████████| 4/4 [00:00<00:00, 95.91it/s]
# generating rows
# 100%|████████████████████████████████████████████| 4/4 [00:00<00:00, 181.83it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  4
# new size:  8
# generating rows
# 100%|███████████████████████████████████████████| 20/20 [00:00<00:00, 75.16it/s]
# generating rows
# 100%|██████████████████████████████████████████| 20/20 [00:00<00:00, 118.86it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  20
# new size:  40
# generating rows
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 104.47it/s]
# generating rows
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 352.10it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  5
# new size:  10
# generating rows
# 100%|████████████████████████████████████████████| 4/4 [00:00<00:00, 120.49it/s]
# generating rows
# 100%|████████████████████████████████████████████| 4/4 [00:00<00:00, 110.88it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  4
# new size:  8
# generating rows
# 100%|█████████████████████████████████████████████| 1/1 [00:00<00:00, 46.65it/s]
# generating rows
# 100%|█████████████████████████████████████████████| 1/1 [00:00<00:00, 61.15it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  1
# new size:  2
# generating rows
# 100%|████████████████████████████████████████████| 8/8 [00:00<00:00, 100.31it/s]
# generating rows
# 100%|█████████████████████████████████████████████| 8/8 [00:00<00:00, 33.23it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  8
# new size:  16
# generating rows
# 100%|█████████████████████████████████████████████| 3/3 [00:00<00:00, 66.46it/s]
# generating rows
# 100%|████████████████████████████████████████████| 3/3 [00:00<00:00, 110.07it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  3
# new size:  6
# generating rows
# 100%|███████████████████████████████████████████| 12/12 [00:00<00:00, 64.61it/s]
# generating rows
# 100%|██████████████████████████████████████████| 12/12 [00:00<00:00, 119.21it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  12
# new size:  24
# generating rows
# 100%|█████████████████████████████████████████████| 3/3 [00:00<00:00, 47.88it/s]
# generating rows
# 100%|████████████████████████████████████████████| 3/3 [00:00<00:00, 130.00it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  3
# new size:  6
# generating rows
# 100%|██████████████████████████████████████████| 16/16 [00:00<00:00, 122.73it/s]
# generating rows
# 100%|██████████████████████████████████████████| 16/16 [00:00<00:00, 109.91it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  16
# new size:  32
# generating rows
# 100%|████████████████████████████████████████████| 3/3 [00:00<00:00, 106.47it/s]
# generating rows
# 100%|█████████████████████████████████████████████| 3/3 [00:00<00:00, 66.55it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  3
# new size:  6
# generating rows
# 100%|██████████████████████████████████████████| 20/20 [00:00<00:00, 102.69it/s]
# generating rows
# 100%|███████████████████████████████████████████| 20/20 [00:00<00:00, 80.55it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  20
# new size:  40
# generating rows
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 141.69it/s]
# generating rows
# 100%|█████████████████████████████████████████████| 5/5 [00:00<00:00, 77.43it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  5
# new size:  10
#
#
#                           )                           (           )       (
#  (                     ( /(               )           )\   (   ( /(   (   )\ )
#  )\   `  )    (    (   )\())   (   (     (     `  )  ((_) ))\  )\()) ))\ (()/(
# ((_)  /(/(    )\   )\ ((_)\    )\  )\    )\  ' /(/(   _  /((_)(_))/ /((_) ((_))
# | __|((_)_\  ((_) ((_)| |(_)  ((_)((_) _((_)) ((_)_\ | |(_))  | |_ (_))   _| |
# | _| | '_ \)/ _ \/ _| | ' \  / _|/ _ \| '  \()| '_ \)| |/ -_) |  _|/ -_)/ _` |
# |___|| .__/ \___/\__| |_||_| \__|\___/|_|_|_| | .__/ |_|\___|  \__|\___|\__,_|
#      |_|                                      |_|
#
# Epoch 1:
# 🔥 Training Loss: 0.847777, Validation Loss: 0.838263
#   0%|                                                    | 0/15 [00:00<?, ?it/s]At Epoch 2:
# generating rows
#
# 100%|████████████████████████████████████████████| 4/4 [00:00<00:00, 100.19it/s]
# generating rows
#
# 100%|█████████████████████████████████████████████| 4/4 [00:00<00:00, 82.73it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  4
# new size:  8
# generating rows
#
#   0%|                                                     | 0/1 [00:00<?, ?it/s]
# 100%|█████████████████████████████████████████████| 1/1 [00:00<00:00,  3.15it/s]
# generating rows
#
# 100%|█████████████████████████████████████████████| 1/1 [00:00<00:00, 10.93it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  1
# new size:  2
# ONE FORWARD PASS DONE
# ONE BACKWARD PASS DONE
#   7%|██▉                                         | 1/15 [00:00<00:12,  1.09it/s]At Epoch 2:
# generating rows
#
#   0%|                                                     | 0/8 [00:00<?, ?it/s]
# 100%|█████████████████████████████████████████████| 8/8 [00:00<00:00, 75.97it/s]
# generating rows
#
# 100%|█████████████████████████████████████████████| 8/8 [00:00<00:00, 97.36it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  8
# new size:  16
# generating rows
#
# 100%|█████████████████████████████████████████████| 3/3 [00:00<00:00, 32.54it/s]
# generating rows
#
# 100%|████████████████████████████████████████████| 3/3 [00:00<00:00, 111.54it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  3
# new size:  6
# ONE FORWARD PASS DONE
# ONE BACKWARD PASS DONE
#  13%|█████▊                                      | 2/15 [00:01<00:11,  1.14it/s]At Epoch 2:
# generating rows
#
#   0%|                                                    | 0/12 [00:00<?, ?it/s]
# 100%|███████████████████████████████████████████| 12/12 [00:00<00:00, 67.48it/s]
# generating rows
#
#   0%|                                                    | 0/12 [00:00<?, ?it/s]
# 100%|██████████████████████████████████████████| 12/12 [00:00<00:00, 108.55it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  12
# new size:  24
# generating rows
#
# 100%|█████████████████████████████████████████████| 3/3 [00:00<00:00, 57.28it/s]
# generating rows
#
# 100%|█████████████████████████████████████████████| 3/3 [00:00<00:00, 41.28it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  3
# new size:  6
# ONE FORWARD PASS DONE
# ONE BACKWARD PASS DONE
#  20%|████████▊                                   | 3/15 [00:02<00:09,  1.21it/s]At Epoch 2:
# generating rows
#
#   0%|                                                    | 0/16 [00:00<?, ?it/s]
#  44%|███████████████████▎                        | 7/16 [00:00<00:00, 63.77it/s]
# 100%|███████████████████████████████████████████| 16/16 [00:00<00:00, 61.86it/s]
# generating rows
#
#   0%|                                                    | 0/16 [00:00<?, ?it/s]
# 100%|██████████████████████████████████████████| 16/16 [00:00<00:00, 100.31it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  16
# new size:  32
# generating rows
#
# 100%|█████████████████████████████████████████████| 5/5 [00:00<00:00, 64.36it/s]
# generating rows
#
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 238.07it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  5
# new size:  10
# ONE FORWARD PASS DONE
# ONE BACKWARD PASS DONE
#  27%|███████████▋                                | 4/15 [00:03<00:10,  1.01it/s]At Epoch 2:
# generating rows
#
#   0%|                                                    | 0/20 [00:00<?, ?it/s]
#  45%|███████████████████▊                        | 9/20 [00:00<00:00, 87.55it/s]
# 100%|███████████████████████████████████████████| 20/20 [00:00<00:00, 74.99it/s]
# generating rows
#
#   0%|                                                    | 0/20 [00:00<?, ?it/s]
#  50%|█████████████████████▌                     | 10/20 [00:00<00:00, 91.43it/s]
# 100%|███████████████████████████████████████████| 20/20 [00:00<00:00, 88.97it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  20
# new size:  40
# generating rows
#
#   0%|                                                     | 0/7 [00:00<?, ?it/s]
# 100%|█████████████████████████████████████████████| 7/7 [00:00<00:00, 60.77it/s]
# generating rows
#
#   0%|                                                     | 0/7 [00:00<?, ?it/s]
# 100%|█████████████████████████████████████████████| 7/7 [00:00<00:00, 69.14it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  7
# new size:  14
# ONE FORWARD PASS DONE
# ONE BACKWARD PASS DONE
#  33%|██████████████▋                             | 5/15 [00:05<00:13,  1.36s/it]At Epoch 2:
# generating rows
#
#   0%|                                                     | 0/4 [00:00<?, ?it/s]
# 100%|█████████████████████████████████████████████| 4/4 [00:00<00:00, 29.20it/s]
# generating rows
#
# 100%|█████████████████████████████████████████████| 4/4 [00:00<00:00, 74.75it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  4
# new size:  8
# generating rows
#
# 100%|████████████████████████████████████████████| 1/1 [00:00<00:00, 396.03it/s]
# generating rows
#
# 100%|█████████████████████████████████████████████| 1/1 [00:00<00:00, 36.54it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  1
# new size:  2
# ONE FORWARD PASS DONE
# ONE BACKWARD PASS DONE
#  40%|█████████████████▌                          | 6/15 [00:06<00:09,  1.07s/it]At Epoch 2:
# generating rows
#
# 100%|█████████████████████████████████████████████| 8/8 [00:00<00:00, 85.23it/s]
# generating rows
#
#   0%|                                                     | 0/8 [00:00<?, ?it/s]
# 100%|█████████████████████████████████████████████| 8/8 [00:00<00:00, 52.65it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  8
# new size:  16
# generating rows
#
# 100%|█████████████████████████████████████████████| 3/3 [00:00<00:00, 84.08it/s]
# generating rows
#
# 100%|█████████████████████████████████████████████| 3/3 [00:00<00:00, 90.38it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  3
# new size:  6
# ONE FORWARD PASS DONE
# ONE BACKWARD PASS DONE
#  47%|████████████████████▌                       | 7/15 [00:06<00:07,  1.06it/s]At Epoch 2:
# generating rows
#
#   0%|                                                    | 0/12 [00:00<?, ?it/s]
# 100%|███████████████████████████████████████████| 12/12 [00:00<00:00, 76.69it/s]
# generating rows
#
#   0%|                                                    | 0/12 [00:00<?, ?it/s]
# 100%|██████████████████████████████████████████| 12/12 [00:00<00:00, 118.16it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  12
# new size:  24
# generating rows
#
# 100%|█████████████████████████████████████████████| 3/3 [00:00<00:00, 59.56it/s]
# generating rows
#
# 100%|████████████████████████████████████████████| 3/3 [00:00<00:00, 342.97it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  3
# new size:  6
# ONE FORWARD PASS DONE
# ONE BACKWARD PASS DONE
#  53%|███████████████████████▍                    | 8/15 [00:07<00:06,  1.10it/s]At Epoch 2:
# generating rows
#
#   0%|                                                    | 0/16 [00:00<?, ?it/s]
# 100%|███████████████████████████████████████████| 16/16 [00:00<00:00, 75.05it/s]
# generating rows
#
#   0%|                                                    | 0/16 [00:00<?, ?it/s]
#  50%|██████████████████████                      | 8/16 [00:00<00:00, 78.28it/s]
# 100%|███████████████████████████████████████████| 16/16 [00:00<00:00, 78.56it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  16
# new size:  32
# generating rows
#
# 100%|█████████████████████████████████████████████| 6/6 [00:00<00:00, 95.78it/s]
# generating rows
#
# 100%|█████████████████████████████████████████████| 6/6 [00:00<00:00, 63.50it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  6
# new size:  12
# ONE FORWARD PASS DONE
# ONE BACKWARD PASS DONE
#  60%|██████████████████████████▍                 | 9/15 [00:09<00:06,  1.03s/it]At Epoch 2:
# generating rows
#
#   0%|                                                    | 0/20 [00:00<?, ?it/s]
# 100%|███████████████████████████████████████████| 20/20 [00:00<00:00, 91.07it/s]
# generating rows
#
#   0%|                                                    | 0/20 [00:00<?, ?it/s]
# 100%|██████████████████████████████████████████| 20/20 [00:00<00:00, 113.38it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  20
# new size:  40
# generating rows
#
# 100%|████████████████████████████████████████████| 7/7 [00:00<00:00, 102.79it/s]
# generating rows
#
# 100%|█████████████████████████████████████████████| 7/7 [00:00<00:00, 73.17it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  7
# new size:  14
# ONE FORWARD PASS DONE
# ONE BACKWARD PASS DONE
#  67%|████████████████████████████▋              | 10/15 [00:10<00:05,  1.18s/it]At Epoch 2:
# generating rows
#
# 100%|█████████████████████████████████████████████| 4/4 [00:00<00:00, 61.82it/s]
# generating rows
#
# 100%|█████████████████████████████████████████████| 4/4 [00:00<00:00, 79.68it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  4
# new size:  8
# generating rows
#
# 100%|█████████████████████████████████████████████| 1/1 [00:00<00:00, 30.64it/s]
# generating rows
#
# 100%|████████████████████████████████████████████| 1/1 [00:00<00:00, 298.25it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  1
# new size:  2
# ONE FORWARD PASS DONE
# ONE BACKWARD PASS DONE
#  73%|███████████████████████████████▌           | 11/15 [00:11<00:03,  1.07it/s]At Epoch 2:
# generating rows
#
# 100%|█████████████████████████████████████████████| 8/8 [00:00<00:00, 88.71it/s]
# generating rows
#
# 100%|█████████████████████████████████████████████| 8/8 [00:00<00:00, 84.80it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  8
# new size:  16
# generating rows
#
# 100%|████████████████████████████████████████████| 3/3 [00:00<00:00, 180.58it/s]
# generating rows
#
# 100%|████████████████████████████████████████████| 3/3 [00:00<00:00, 183.40it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  3
# new size:  6
# ONE FORWARD PASS DONE
# ONE BACKWARD PASS DONE
#  80%|██████████████████████████████████▍        | 12/15 [00:11<00:02,  1.18it/s]At Epoch 2:
# generating rows
#
#   0%|                                                    | 0/12 [00:00<?, ?it/s]
# 100%|███████████████████████████████████████████| 12/12 [00:00<00:00, 98.22it/s]
# generating rows
#
#   0%|                                                    | 0/12 [00:00<?, ?it/s]
# 100%|███████████████████████████████████████████| 12/12 [00:00<00:00, 96.92it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  12
# new size:  24
# generating rows
#
# 100%|████████████████████████████████████████████| 3/3 [00:00<00:00, 118.86it/s]
# generating rows
#
#   0%|                                                     | 0/3 [00:00<?, ?it/s]
# 100%|█████████████████████████████████████████████| 3/3 [00:00<00:00, 24.82it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  3
# new size:  6
# ONE FORWARD PASS DONE
# ONE BACKWARD PASS DONE
#  87%|█████████████████████████████████████▎     | 13/15 [00:12<00:01,  1.16it/s]At Epoch 2:
# generating rows
#
#   0%|                                                    | 0/16 [00:00<?, ?it/s]
#  38%|████████████████▌                           | 6/16 [00:00<00:00, 56.68it/s]
# 100%|███████████████████████████████████████████| 16/16 [00:00<00:00, 75.10it/s]
# generating rows
#
#   0%|                                                    | 0/16 [00:00<?, ?it/s]
# 100%|███████████████████████████████████████████| 16/16 [00:00<00:00, 91.40it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  16
# new size:  32
# generating rows
#
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 107.26it/s]
# generating rows
#
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 141.05it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  5
# new size:  10
# ONE FORWARD PASS DONE
# ONE BACKWARD PASS DONE
#  93%|████████████████████████████████████████▏  | 14/15 [00:13<00:00,  1.01it/s]At Epoch 2:
# generating rows
#
#   0%|                                                    | 0/20 [00:00<?, ?it/s]
#  45%|███████████████████▊                        | 9/20 [00:00<00:00, 77.44it/s]
# 100%|███████████████████████████████████████████| 20/20 [00:00<00:00, 87.68it/s]
# generating rows
#
#   0%|                                                    | 0/20 [00:00<?, ?it/s]
#  50%|█████████████████████▌                     | 10/20 [00:00<00:00, 50.98it/s]
# 100%|███████████████████████████████████████████| 20/20 [00:00<00:00, 67.19it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  20
# new size:  40
# generating rows
#
# 100%|█████████████████████████████████████████████| 7/7 [00:00<00:00, 71.41it/s]
# generating rows
#
#   0%|                                                     | 0/7 [00:00<?, ?it/s]
# 100%|█████████████████████████████████████████████| 7/7 [00:00<00:00, 32.86it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  7
# new size:  14
# ONE FORWARD PASS DONE
# ONE BACKWARD PASS DONE
# 100%|███████████████████████████████████████████| 15/15 [00:15<00:00,  1.03s/it]
# generating rows
# 100%|████████████████████████████████████████████| 4/4 [00:00<00:00, 124.55it/s]
# generating rows
# 100%|█████████████████████████████████████████████| 4/4 [00:00<00:00, 66.63it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  4
# new size:  8
# generating rows
# 100%|█████████████████████████████████████████████| 1/1 [00:00<00:00, 89.10it/s]
# generating rows
# 100%|████████████████████████████████████████████| 1/1 [00:00<00:00, 222.42it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  1
# new size:  2
# generating rows
# 100%|█████████████████████████████████████████████| 8/8 [00:00<00:00, 86.92it/s]
# generating rows
# 100%|████████████████████████████████████████████| 8/8 [00:00<00:00, 105.83it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  8
# new size:  16
# generating rows
# 100%|████████████████████████████████████████████| 3/3 [00:00<00:00, 107.63it/s]
# generating rows
# 100%|█████████████████████████████████████████████| 3/3 [00:00<00:00, 32.68it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  3
# new size:  6
# generating rows
# 100%|██████████████████████████████████████████| 12/12 [00:00<00:00, 128.52it/s]
# generating rows
# 100%|██████████████████████████████████████████| 12/12 [00:00<00:00, 125.98it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  12
# new size:  24
# generating rows
# 100%|████████████████████████████████████████████| 3/3 [00:00<00:00, 148.71it/s]
# generating rows
# 100%|█████████████████████████████████████████████| 3/3 [00:00<00:00, 64.87it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  3
# new size:  6
# generating rows
# 100%|███████████████████████████████████████████| 16/16 [00:00<00:00, 87.25it/s]
# generating rows
# 100%|██████████████████████████████████████████| 16/16 [00:00<00:00, 119.84it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  16
# new size:  32
# generating rows
# 100%|█████████████████████████████████████████████| 5/5 [00:00<00:00, 51.10it/s]
# generating rows
# 100%|█████████████████████████████████████████████| 5/5 [00:00<00:00, 64.19it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  5
# new size:  10
# generating rows
# 100%|██████████████████████████████████████████| 20/20 [00:00<00:00, 149.32it/s]
# generating rows
# 100%|██████████████████████████████████████████| 20/20 [00:00<00:00, 145.25it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  20
# new size:  40
# generating rows
# 100%|████████████████████████████████████████████| 7/7 [00:00<00:00, 109.59it/s]
# generating rows
# 100%|████████████████████████████████████████████| 7/7 [00:00<00:00, 174.46it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  7
# new size:  14
# generating rows
# 100%|████████████████████████████████████████████| 4/4 [00:00<00:00, 140.69it/s]
# generating rows
# 100%|████████████████████████████████████████████| 4/4 [00:00<00:00, 136.28it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  4
# new size:  8
# generating rows
# 100%|████████████████████████████████████████████| 1/1 [00:00<00:00, 212.54it/s]
# generating rows
# 100%|█████████████████████████████████████████████| 1/1 [00:00<00:00, 29.57it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  1
# new size:  2
# generating rows
# 100%|████████████████████████████████████████████| 8/8 [00:00<00:00, 148.65it/s]
# generating rows
# 100%|████████████████████████████████████████████| 8/8 [00:00<00:00, 199.65it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  8
# new size:  16
# generating rows
# 100%|████████████████████████████████████████████| 3/3 [00:00<00:00, 146.71it/s]
# generating rows
# 100%|████████████████████████████████████████████| 3/3 [00:00<00:00, 119.57it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  3
# new size:  6
# generating rows
# 100%|██████████████████████████████████████████| 12/12 [00:00<00:00, 133.20it/s]
# generating rows
# 100%|██████████████████████████████████████████| 12/12 [00:00<00:00, 121.49it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  12
# new size:  24
# generating rows
# 100%|████████████████████████████████████████████| 4/4 [00:00<00:00, 172.61it/s]
# generating rows
# 100%|████████████████████████████████████████████| 4/4 [00:00<00:00, 111.74it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  4
# new size:  8
# generating rows
# 100%|██████████████████████████████████████████| 16/16 [00:00<00:00, 149.89it/s]
# generating rows
# 100%|██████████████████████████████████████████| 16/16 [00:00<00:00, 159.97it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  16
# new size:  32
# generating rows
# 100%|████████████████████████████████████████████| 4/4 [00:00<00:00, 193.79it/s]
# generating rows
# 100%|█████████████████████████████████████████████| 4/4 [00:00<00:00, 91.01it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  4
# new size:  8
# generating rows
# 100%|██████████████████████████████████████████| 20/20 [00:00<00:00, 142.14it/s]
# generating rows
# 100%|██████████████████████████████████████████| 20/20 [00:00<00:00, 107.71it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  20
# new size:  40
# generating rows
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 158.60it/s]
# generating rows
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 117.69it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  5
# new size:  10
# generating rows
# 100%|█████████████████████████████████████████████| 4/4 [00:00<00:00, 77.31it/s]
# generating rows
# 100%|█████████████████████████████████████████████| 4/4 [00:00<00:00, 48.28it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  4
# new size:  8
# generating rows
# 100%|████████████████████████████████████████████| 1/1 [00:00<00:00, 406.35it/s]
# generating rows
# 100%|████████████████████████████████████████████| 1/1 [00:00<00:00, 124.14it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  1
# new size:  2
# generating rows
# 100%|█████████████████████████████████████████████| 8/8 [00:00<00:00, 37.56it/s]
# generating rows
# 100%|█████████████████████████████████████████████| 8/8 [00:00<00:00, 92.85it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  8
# new size:  16
# generating rows
# 100%|█████████████████████████████████████████████| 3/3 [00:00<00:00, 45.10it/s]
# generating rows
# 100%|████████████████████████████████████████████| 3/3 [00:00<00:00, 263.37it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  3
# new size:  6
# generating rows
# 100%|███████████████████████████████████████████| 12/12 [00:00<00:00, 69.27it/s]
# generating rows
# 100%|██████████████████████████████████████████| 12/12 [00:00<00:00, 195.11it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  12
# new size:  24
# generating rows
# 100%|████████████████████████████████████████████| 3/3 [00:00<00:00, 119.23it/s]
# generating rows
# 100%|█████████████████████████████████████████████| 3/3 [00:00<00:00, 73.57it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  3
# new size:  6
# generating rows
# 100%|██████████████████████████████████████████| 16/16 [00:00<00:00, 115.21it/s]
# generating rows
# 100%|██████████████████████████████████████████| 16/16 [00:00<00:00, 116.19it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  16
# new size:  32
# generating rows
# 100%|████████████████████████████████████████████| 3/3 [00:00<00:00, 102.17it/s]
# generating rows
# 100%|█████████████████████████████████████████████| 3/3 [00:00<00:00, 58.59it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  3
# new size:  6
# generating rows
# 100%|██████████████████████████████████████████| 20/20 [00:00<00:00, 132.26it/s]
# generating rows
# 100%|███████████████████████████████████████████| 20/20 [00:00<00:00, 80.16it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  20
# new size:  40
# generating rows
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 104.76it/s]
# generating rows
# 100%|█████████████████████████████████████████████| 5/5 [00:00<00:00, 80.50it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  5
# new size:  10
#
#
#                           )                           (           )       (
#  (                     ( /(               )           )\   (   ( /(   (   )\ )
#  )\   `  )    (    (   )\())   (   (     (     `  )  ((_) ))\  )\()) ))\ (()/(
# ((_)  /(/(    )\   )\ ((_)\    )\  )\    )\  ' /(/(   _  /((_)(_))/ /((_) ((_))
# | __|((_)_\  ((_) ((_)| |(_)  ((_)((_) _((_)) ((_)_\ | |(_))  | |_ (_))   _| |
# | _| | '_ \)/ _ \/ _| | ' \  / _|/ _ \| '  \()| '_ \)| |/ -_) |  _|/ -_)/ _` |
# |___|| .__/ \___/\__| |_||_| \__|\___/|_|_|_| | .__/ |_|\___|  \__|\___|\__,_|
#      |_|                                      |_|
#
# Epoch 2:
# 🔥 Training Loss: 0.833105, Validation Loss: 0.851179
#
#
#
#
#
#                           .--.   _..._   .--.   _..._
#                           |__| .'     '. |__| .'     '.   .--./)
#      .|  .-,.--.          .--..   .-.   ..--..   .-.   . /.''\
#    .' |_ |  .-. |    __   |  ||  '   '  ||  ||  '   '  || |  | |
#  .'     || |  | | .:--.'. |  ||  |   |  ||  ||  |   |  | \`-' /
# '--.  .-'| |  | |/ |   \ ||  ||  |   |  ||  ||  |   |  | /("'`
#    |  |  | |  '- `" __ | ||  ||  |   |  ||  ||  |   |  | \ '---.
#    |  |  | |      .'.''| ||__||  |   |  ||__||  |   |  |  /'""'.\
#    |  '.'| |     / /   | |_   |  |   |  |    |  |   |  | ||     ||
#    |   / |_|     \ \._,\ '/   |  |   |  |    |  |   |  | '. __//
#    `'-'           `--'  `"    '--'   '--'    '--'   '--'  `'---'
#        _..._       .-'''-.
#     .-'_..._''.   '   _    \                                         .---.                                                _______
#   .' .'      '.\/   /` '.   \  __  __   ___  _________   _...._      |   |      __.....__                    __.....__    \  ___ `'.
#  / .'          .   |     \  ' |  |/  `.'   `.\        |.'      '-.   |   |  .-''         '.              .-''         '.   ' |--.\  \
# . '            |   '      |  '|   .-.  .-.   '\        .'```'.    '. |   | /     .-''"'-.  `.      .|   /     .-''"'-.  `. | |    \  '
# | |            \    \     / / |  |  |  |  |  | \      |       \     \|   |/     /________\   \   .' |_ /     /________\   \| |     |  '
# | |             `.   ` ..' /  |  |  |  |  |  |  |     |        |    ||   ||                  | .'     ||                  || |     |  |
# . '                '-...-'`   |  |  |  |  |  |  |      \      /    . |   |\    .-------------''--.  .-'\    .-------------'| |     ' .'
#  \ '.          .              |  |  |  |  |  |  |     |\`'-.-'   .'  |   | \    '-.____...---.   |  |   \    '-.____...---.| |___.' /'
#   '. `._____.-'/              |__|  |__|  |__|  |     | '-....-'`    |   |  `.             .'    |  |    `.             .'/_______.'/
#     `-.______ /                                .'     '.             '---'    `''-...... -'      |  '.'    `''-...... -'  \_______|/
#              `                               '-----------'                                       |   /
#                                                                                                  `'-'
#
#                                 |_|
#
# Copied ../experiments/damcc_ba_2025-02-24_13-45-57 to ../experiments/last_experiment

# %% [markdown]
# We now test:

# %%
# Run the DAMCC model in test mode using the specified parameters
# --test: flag to indicate test mode
# --data_name: name of the dataset
# --test_file: path to the test data file in CC format
# --test_graphs_file: path to the raw test graphs file
# --model_path: path to the trained model file
# --save_dir: directory where the test results and other outputs will be saved
# !python ../run_damcc.py \
    --test \
    --data_name ba \
    --test_file ../data/processed_datasets/ba/CC_data/ba_test_ccs.pkl \
    --test_graphs_file ../data/processed_datasets/ba/graph_data/ba_test_graphs_raw.pkl \
    --model_path ../experiments/last_experiment/best_val_model.pth \
    --save_dir ../experiments/last_experiment/
# Out:
# Using device: cpu
# /opt/anaconda3/envs/damcc_eval/lib/python3.11/site-packages/topomodelx/nn/combinatorial/hmc_layer.py:680: UserWarning: Sparse CSR tensor support is in beta state. If you miss a functionality in the sparse tensor support, please submit a feature request to https://github.com/pytorch/pytorch/issues. (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/SparseCsrTensorImpl.cpp:56.)
#   A_p = torch.sparse.mm(A_p, neighborhood)
# generating rows
# 100%|████████████████████████████████████████████| 4/4 [00:00<00:00, 131.78it/s]
# generating rows
# 100%|████████████████████████████████████████████| 4/4 [00:00<00:00, 100.41it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  4
# new size:  8
# generating rows
# 100%|████████████████████████████████████████████| 1/1 [00:00<00:00, 204.95it/s]
# generating rows
# 100%|█████████████████████████████████████████████| 1/1 [00:00<00:00, 36.48it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  1
# new size:  2
# generating rows
# 100%|█████████████████████████████████████████████| 8/8 [00:00<00:00, 90.00it/s]
# generating rows
# 100%|████████████████████████████████████████████| 8/8 [00:00<00:00, 106.20it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  8
# new size:  16
# generating rows
# 100%|█████████████████████████████████████████████| 3/3 [00:00<00:00, 49.76it/s]
# generating rows
# 100%|████████████████████████████████████████████| 3/3 [00:00<00:00, 380.82it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  3
# new size:  6
# generating rows
# 100%|██████████████████████████████████████████| 12/12 [00:00<00:00, 152.12it/s]
# generating rows
# 100%|██████████████████████████████████████████| 12/12 [00:00<00:00, 149.61it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  12
# new size:  24
# generating rows
# 100%|█████████████████████████████████████████████| 5/5 [00:00<00:00, 82.04it/s]
# generating rows
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 104.00it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  5
# new size:  10
# generating rows
# 100%|███████████████████████████████████████████| 16/16 [00:00<00:00, 85.65it/s]
# generating rows
# 100%|██████████████████████████████████████████| 16/16 [00:00<00:00, 115.47it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  16
# new size:  32
# generating rows
# 100%|█████████████████████████████████████████████| 5/5 [00:00<00:00, 73.77it/s]
# generating rows
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 124.64it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  5
# new size:  10
# generating rows
# 100%|██████████████████████████████████████████| 20/20 [00:00<00:00, 157.41it/s]
# generating rows
# 100%|███████████████████████████████████████████| 20/20 [00:00<00:00, 61.72it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  20
# new size:  40
# generating rows
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 131.83it/s]
# generating rows
# 100%|█████████████████████████████████████████████| 5/5 [00:00<00:00, 67.32it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  5
# new size:  10
# generating rows
# 100%|█████████████████████████████████████████████| 4/4 [00:00<00:00, 99.84it/s]
# generating rows
# 100%|████████████████████████████████████████████| 4/4 [00:00<00:00, 152.94it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  4
# new size:  8
# generating rows
# 100%|████████████████████████████████████████████| 1/1 [00:00<00:00, 320.42it/s]
# generating rows
# 100%|█████████████████████████████████████████████| 1/1 [00:00<00:00, 48.51it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  1
# new size:  2
# generating rows
# 100%|█████████████████████████████████████████████| 8/8 [00:00<00:00, 88.56it/s]
# generating rows
# 100%|████████████████████████████████████████████| 8/8 [00:00<00:00, 191.22it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  8
# new size:  16
# generating rows
# 100%|█████████████████████████████████████████████| 3/3 [00:00<00:00, 56.60it/s]
# generating rows
# 100%|█████████████████████████████████████████████| 3/3 [00:00<00:00, 92.86it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  3
# new size:  6
# generating rows
# 100%|███████████████████████████████████████████| 12/12 [00:00<00:00, 74.50it/s]
# generating rows
# 100%|██████████████████████████████████████████| 12/12 [00:00<00:00, 128.09it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  12
# new size:  24
# generating rows
# 100%|█████████████████████████████████████████████| 4/4 [00:00<00:00, 50.94it/s]
# generating rows
# 100%|████████████████████████████████████████████| 4/4 [00:00<00:00, 103.36it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  4
# new size:  8
# generating rows
# 100%|██████████████████████████████████████████| 16/16 [00:00<00:00, 123.62it/s]
# generating rows
# 100%|██████████████████████████████████████████| 16/16 [00:00<00:00, 138.59it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  16
# new size:  32
# generating rows
# 100%|█████████████████████████████████████████████| 5/5 [00:00<00:00, 70.53it/s]
# generating rows
# 100%|█████████████████████████████████████████████| 5/5 [00:00<00:00, 66.54it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  5
# new size:  10
# generating rows
# 100%|██████████████████████████████████████████| 20/20 [00:00<00:00, 104.01it/s]
# generating rows
# 100%|██████████████████████████████████████████| 20/20 [00:00<00:00, 156.26it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  20
# new size:  40
# generating rows
# 100%|█████████████████████████████████████████████| 5/5 [00:00<00:00, 81.93it/s]
# generating rows
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 169.42it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  5
# new size:  10
# generating rows
# 100%|█████████████████████████████████████████████| 4/4 [00:00<00:00, 75.75it/s]
# generating rows
# 100%|█████████████████████████████████████████████| 4/4 [00:00<00:00, 71.61it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  4
# new size:  8
# generating rows
# 100%|████████████████████████████████████████████| 1/1 [00:00<00:00, 167.02it/s]
# generating rows
# 100%|█████████████████████████████████████████████| 1/1 [00:00<00:00, 41.20it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  1
# new size:  2
# generating rows
# 100%|█████████████████████████████████████████████| 8/8 [00:00<00:00, 80.43it/s]
# generating rows
# 100%|█████████████████████████████████████████████| 8/8 [00:00<00:00, 94.64it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  8
# new size:  16
# generating rows
# 100%|████████████████████████████████████████████| 3/3 [00:00<00:00, 104.70it/s]
# generating rows
# 100%|█████████████████████████████████████████████| 3/3 [00:00<00:00, 48.62it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  3
# new size:  6
# generating rows
# 100%|███████████████████████████████████████████| 12/12 [00:00<00:00, 85.63it/s]
# generating rows
# 100%|██████████████████████████████████████████| 12/12 [00:00<00:00, 156.26it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  12
# new size:  24
# generating rows
# 100%|████████████████████████████████████████████| 4/4 [00:00<00:00, 137.70it/s]
# generating rows
# 100%|████████████████████████████████████████████| 4/4 [00:00<00:00, 110.79it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  4
# new size:  8
# generating rows
# 100%|███████████████████████████████████████████| 16/16 [00:00<00:00, 72.34it/s]
# generating rows
# 100%|███████████████████████████████████████████| 16/16 [00:00<00:00, 61.90it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  16
# new size:  32
# generating rows
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 116.98it/s]
# generating rows
# 100%|█████████████████████████████████████████████| 5/5 [00:00<00:00, 62.87it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  5
# new size:  10
# generating rows
# 100%|██████████████████████████████████████████| 20/20 [00:00<00:00, 102.69it/s]
# generating rows
# 100%|██████████████████████████████████████████| 20/20 [00:00<00:00, 135.48it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  20
# new size:  40
# generating rows
# 100%|█████████████████████████████████████████████| 5/5 [00:00<00:00, 64.39it/s]
# generating rows
# 100%|█████████████████████████████████████████████| 5/5 [00:00<00:00, 56.08it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  5
# new size:  10
# generating rows
# 100%|█████████████████████████████████████████████| 4/4 [00:00<00:00, 54.41it/s]
# generating rows
# 100%|████████████████████████████████████████████| 4/4 [00:00<00:00, 119.84it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  4
# new size:  8
# generating rows
# 100%|█████████████████████████████████████████████| 1/1 [00:00<00:00, 66.12it/s]
# generating rows
# 100%|█████████████████████████████████████████████| 1/1 [00:00<00:00, 52.00it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  1
# new size:  2
# generating rows
# 100%|█████████████████████████████████████████████| 8/8 [00:00<00:00, 60.09it/s]
# generating rows
# 100%|████████████████████████████████████████████| 8/8 [00:00<00:00, 143.15it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  8
# new size:  16
# generating rows
# 100%|████████████████████████████████████████████| 3/3 [00:00<00:00, 110.39it/s]
# generating rows
# 100%|████████████████████████████████████████████| 3/3 [00:00<00:00, 149.82it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  3
# new size:  6
# generating rows
# 100%|██████████████████████████████████████████| 12/12 [00:00<00:00, 133.80it/s]
# generating rows
# 100%|██████████████████████████████████████████| 12/12 [00:00<00:00, 107.99it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  12
# new size:  24
# generating rows
# 100%|█████████████████████████████████████████████| 3/3 [00:00<00:00, 27.95it/s]
# generating rows
# 100%|████████████████████████████████████████████| 3/3 [00:00<00:00, 158.91it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  3
# new size:  6
# generating rows
# 100%|███████████████████████████████████████████| 16/16 [00:00<00:00, 73.07it/s]
# generating rows
# 100%|███████████████████████████████████████████| 16/16 [00:00<00:00, 79.53it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  16
# new size:  32
# generating rows
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 144.31it/s]
# generating rows
# 100%|█████████████████████████████████████████████| 5/5 [00:00<00:00, 68.29it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  5
# new size:  10
# generating rows
# 100%|███████████████████████████████████████████| 20/20 [00:00<00:00, 95.51it/s]
# generating rows
# 100%|██████████████████████████████████████████| 20/20 [00:00<00:00, 118.33it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  20
# new size:  40
# generating rows
# 100%|████████████████████████████████████████████| 7/7 [00:00<00:00, 146.75it/s]
# generating rows
# 100%|█████████████████████████████████████████████| 7/7 [00:00<00:00, 75.86it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  7
# new size:  14
# generating rows
# 100%|████████████████████████████████████████████| 4/4 [00:00<00:00, 131.51it/s]
# generating rows
# 100%|████████████████████████████████████████████| 4/4 [00:00<00:00, 143.77it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  4
# new size:  8
# generating rows
# 100%|████████████████████████████████████████████| 1/1 [00:00<00:00, 322.29it/s]
# generating rows
# 100%|████████████████████████████████████████████| 1/1 [00:00<00:00, 189.03it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  1
# new size:  2
# generating rows
# 100%|████████████████████████████████████████████| 8/8 [00:00<00:00, 118.15it/s]
# generating rows
# 100%|████████████████████████████████████████████| 8/8 [00:00<00:00, 142.96it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  8
# new size:  16
# generating rows
# 100%|█████████████████████████████████████████████| 3/3 [00:00<00:00, 41.92it/s]
# generating rows
# 100%|█████████████████████████████████████████████| 3/3 [00:00<00:00, 88.50it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  3
# new size:  6
# generating rows
# 100%|███████████████████████████████████████████| 12/12 [00:00<00:00, 55.20it/s]
# generating rows
# 100%|██████████████████████████████████████████| 12/12 [00:00<00:00, 112.55it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  12
# new size:  24
# generating rows
# 100%|████████████████████████████████████████████| 3/3 [00:00<00:00, 212.87it/s]
# generating rows
# 100%|████████████████████████████████████████████| 3/3 [00:00<00:00, 159.05it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  3
# new size:  6
# generating rows
# 100%|███████████████████████████████████████████| 16/16 [00:00<00:00, 97.28it/s]
# generating rows
# 100%|███████████████████████████████████████████| 16/16 [00:00<00:00, 85.61it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  16
# new size:  32
# generating rows
# 100%|█████████████████████████████████████████████| 5/5 [00:00<00:00, 69.45it/s]
# generating rows
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 332.71it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  5
# new size:  10
# generating rows
# 100%|███████████████████████████████████████████| 20/20 [00:00<00:00, 97.48it/s]
# generating rows
# 100%|██████████████████████████████████████████| 20/20 [00:00<00:00, 105.84it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  20
# new size:  40
# generating rows
# 100%|█████████████████████████████████████████████| 5/5 [00:00<00:00, 51.80it/s]
# generating rows
# 100%|█████████████████████████████████████████████| 5/5 [00:00<00:00, 94.34it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  5
# new size:  10
# generating rows
# 100%|█████████████████████████████████████████████| 4/4 [00:00<00:00, 59.94it/s]
# generating rows
# 100%|████████████████████████████████████████████| 4/4 [00:00<00:00, 154.02it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  4
# new size:  8
# generating rows
# 100%|████████████████████████████████████████████| 1/1 [00:00<00:00, 711.14it/s]
# generating rows
# 100%|████████████████████████████████████████████| 1/1 [00:00<00:00, 329.92it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  1
# new size:  2
# generating rows
# 100%|█████████████████████████████████████████████| 8/8 [00:00<00:00, 53.25it/s]
# generating rows
# 100%|█████████████████████████████████████████████| 8/8 [00:00<00:00, 72.43it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  8
# new size:  16
# generating rows
# 100%|█████████████████████████████████████████████| 3/3 [00:00<00:00, 87.46it/s]
# generating rows
# 100%|█████████████████████████████████████████████| 3/3 [00:00<00:00, 86.83it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  3
# new size:  6
# generating rows
# 100%|██████████████████████████████████████████| 12/12 [00:00<00:00, 121.27it/s]
# generating rows
# 100%|██████████████████████████████████████████| 12/12 [00:00<00:00, 129.08it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  12
# new size:  24
# generating rows
# 100%|████████████████████████████████████████████| 6/6 [00:00<00:00, 232.79it/s]
# generating rows
# 100%|████████████████████████████████████████████| 6/6 [00:00<00:00, 120.17it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  6
# new size:  12
# generating rows
# 100%|██████████████████████████████████████████| 16/16 [00:00<00:00, 112.65it/s]
# generating rows
# 100%|███████████████████████████████████████████| 16/16 [00:00<00:00, 35.41it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  16
# new size:  32
# generating rows
# 100%|█████████████████████████████████████████████| 6/6 [00:00<00:00, 92.40it/s]
# generating rows
# 100%|████████████████████████████████████████████| 6/6 [00:00<00:00, 116.49it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  6
# new size:  12
# generating rows
# 100%|███████████████████████████████████████████| 20/20 [00:00<00:00, 93.32it/s]
# generating rows
# 100%|██████████████████████████████████████████| 20/20 [00:00<00:00, 104.87it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  20
# new size:  40
# generating rows
# 100%|████████████████████████████████████████████| 6/6 [00:00<00:00, 180.88it/s]
# generating rows
# 100%|█████████████████████████████████████████████| 6/6 [00:00<00:00, 50.51it/s]
# RETURNING INCIDENCE MATRIX
# incidence matrix size was:  6
# new size:  12
#
#    ■  ▗▞▀▚▖ ▄▄▄  ■         ▐▌▗▞▀▜▌   ■  ▗▞▀▜▌     ▄▄▄ ▗▞▀▜▌▄   ▄ ▗▞▀▚▖   ▐▌
# ▗▄▟▙▄▖▐▛▀▀▘▀▄▄▗▄▟▙▄▖       ▐▌▝▚▄▟▌▗▄▟▙▄▖▝▚▄▟▌    ▀▄▄  ▝▚▄▟▌█   █ ▐▛▀▀▘   ▐▌
#   ▐▌  ▝▚▄▄▖▄▄▄▀ ▐▌      ▗▞▀▜▌       ▐▌           ▄▄▄▀       ▀▄▀  ▝▚▄▄▖▗▞▀▜▌
#   ▐▌            ▐▌      ▝▚▄▟▌       ▐▌                                ▝▚▄▟▌
#   ▐▌            ▐▌                  ▐▌
#
#
# Test results saved to ../experiments/last_experiment/test

# %% [markdown]
# Let us see what the Sampled graphs look like:

# %%
# Open the file containing the generated data and load it using pickle
with open('../experiments/last_experiment/test/sampled_graphs.pkl', 'rb') as file:
    generated_data = pickle.load(file)

# Create a figure with subplots for each graph in the first sequence of generated data
fig, axes = plt.subplots(2, len(generated_data[0]) // 2, figsize=(20, 11))
axes = axes.flatten()  # Flatten the 2D array of axes

# Iterate over each graph in the first sequence of generated data and plot it
for i, graph in enumerate(generated_data[0]):
    ax = axes[i]
    nx.draw(graph, pos, with_labels=True, node_color='skyblue', node_size=250, edge_color='gray', 
            font_size=10, font_color='black', font_weight='bold', ax=ax)
    ax.set_title(f"Timestep {i+1}")

# Display the plot
plt.show()

# %% [markdown]
# We now evaluate. Note that in the original paper we us ethe evaluation teqchniques introduced in [this link](https://dl.acm.org/doi/10.1145/3642970.3655829). The code for that is not available as teh authors asked it to not be shared. However the evaluation we provide here is from [DAMNETS](https://arxiv.org/abs/2203.15009) and originally available on [github](https://github.com/jase-clarkson/DAMNETS_LoG).

# %%
# !python ../eval.py \
    --sampled_path ../experiments/last_experiment/test/sampled_graphs.pkl \
    --test_path ../data/processed_datasets/ba/graph_data/ba_test_graphs_raw.pkl \
    --dataset_name ba \
    --model_name damcc \
    --output_dir ../eval
# Out:
# Computing statistics for model damcc
# Computing Density
# Computing Clustering
# Computing Transitivity
# Computing Assortativity
# Computing Closeness
# Computing statistics for model Test
# Computing Density
# Computing Clustering
# Computing Transitivity
# Computing Assortativity
# Computing Closeness
# Computing Local MMDs
# 100%|█████████████████████████████████████████████| 5/5 [00:00<00:00, 20.57it/s]
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 127.90it/s]
# ------ Sum MMDs ------
# damcc  Degree_MMD        1.206006
#        Clustering_MMD    4.457394
#        Spectral_MMD      0.707770
#        Trans_MMD         1.804275
#        Assort_MMD        1.025483
#        CC_MMD            0.708898
# dtype: float64

# %%
from IPython.display import Image

# Display the image
Image(filename='../eval/damcc_network_statistics.jpg', width=2000, height=300)

# %%
Image(filename='../eval/damcc_ba_degree.jpg', width=800)
